# %% [markdown]
# # Importing the necessary tools

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np
import re
import seaborn as sns
from IPython.display import display_html
from itertools import chain,cycle

# %%
# Importing the file.csv

sharks = pd.read_csv("../data/attacks.csv", header = 0, encoding= 'unicode_escape')

# %%
# This is a function to display multiple tables in the same row

def display_side_by_side(*args,titles=cycle([''])):
    html_str=''
    for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        html_str+=f'<h2 style="text-align: center;">{title}</h2>'
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+='</td></th>'
    display_html(html_str,raw=True)

# %% [markdown]
# # First info about the dataset: shape, columns...

# %%
# First info

print(f"The shape is now {sharks.shape}")
# Out:
# The shape is now (25723, 24)

# %%
# Displaying Describe and Head tables
display_side_by_side(sharks.describe(), pd.DataFrame(sharks.columns),sharks.sample(6), titles=['Describe', "Column names", 'Head'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Describe</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>original order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>6300.000000</td>
#       <td>6309.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>1927.272381</td>
#       <td>3155.999683</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>281.116308</td>
#       <td>1821.396206</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.000000</td>
#       <td>2.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>1942.000000</td>
#       <td>1579.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>1977.000000</td>
#       <td>3156.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>2005.000000</td>
#       <td>4733.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>2018.000000</td>
#       <td>6310.000000</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Column names</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Case Number</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Date</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Year</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Type</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Country</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Area</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Location</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Activity</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Name</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Sex</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Age</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Injury</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Fatal (Y/N)</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Time</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Species</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Investigator or Source</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>pdf</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>href formula</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>href</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Case Number.1</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Case Number.2</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>original order</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Unnamed: 22</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Unnamed: 23</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Head</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Case Number</th>
#       <th>Date</th>
#       <th>Year</th>
#       <th>Type</th>
#       <th>Country</th>
#       <th>Area</th>
#       <th>Location</th>
#       <th>Activity</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>Injury</th>
#       <th>Fatal (Y/N)</th>
#       <th>Time</th>
#       <th>Species</th>
#       <th>Investigator or Source</th>
#       <th>pdf</th>
#       <th>href formula</th>
#       <th>href</th>
#       <th>Case Number.1</th>
#       <th>Case Number.2</th>
#       <th>original order</th>
#       <th>Unnamed: 22</th>
#       <th>Unnamed: 23</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18669</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>8026</th>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1570</th>
#       <td>2005.07.15</td>
#       <td>15-Jul-2005</td>
#       <td>2005.0</td>
#       <td>Unprovoked</td>
#       <td>USA</td>
#       <td>North Carolina</td>
#       <td>Holden Beach, Brunswick County</td>
#       <td>Swimming</td>
#       <td>Chris Humphrey</td>
#       <td>M</td>
#       <td>22</td>
#       <td>Lacerations of left forearm</td>
#       <td>N</td>
#       <td>16h40</td>
#       <td>[4.5' to 5'] shark</td>
#       <td>C. Creswell, GSAF</td>
#       <td>2005.07.15.a-Humphrey.pdf</td>
#       <td>http://sharkattackfile.net/spreadsheets/pdf_directory/2005.07.15.a-Humphrey.pdf</td>
#       <td>http://sharkattackfile.net/spreadsheets/pdf_directory/2005.07.15.a-Humphrey.pdf</td>
#       <td>2005.07.15</td>
#       <td>2005.07.15</td>
#       <td>4733.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>23234</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>25510</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>12071</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %%
#Custom function to display errors

def display_errors(df):
    
    total_nas = pd.DataFrame(df.isna().sum())
    total_null = pd.DataFrame(df.isnull().sum())
    duplicated = pd.DataFrame(df.duplicated().value_counts())


    return display_side_by_side(total_nas, total_null, duplicated, titles=['Sum of NAs', "Sum of Nuls", "Number of Duplicates"])

# %%
# Display of the errors

display_errors(sharks)
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of NAs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Case Number</th>
#       <td>17021</td>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>19423</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>19425</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>19471</td>
#     </tr>
#     <tr>
#       <th>Area</th>
#       <td>19876</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>19961</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>19965</td>
#     </tr>
#     <tr>
#       <th>Name</th>
#       <td>19631</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>19986</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>22252</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>19449</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>19960</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>22775</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>22259</td>
#     </tr>
#     <tr>
#       <th>Investigator or Source</th>
#       <td>19438</td>
#     </tr>
#     <tr>
#       <th>pdf</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>href formula</th>
#       <td>19422</td>
#     </tr>
#     <tr>
#       <th>href</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Case Number.1</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Case Number.2</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>original order</th>
#       <td>19414</td>
#     </tr>
#     <tr>
#       <th>Unnamed: 22</th>
#       <td>25722</td>
#     </tr>
#     <tr>
#       <th>Unnamed: 23</th>
#       <td>25721</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of Nuls</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Case Number</th>
#       <td>17021</td>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>19423</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>19425</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>19471</td>
#     </tr>
#     <tr>
#       <th>Area</th>
#       <td>19876</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>19961</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>19965</td>
#     </tr>
#     <tr>
#       <th>Name</th>
#       <td>19631</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>19986</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>22252</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>19449</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>19960</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>22775</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>22259</td>
#     </tr>
#     <tr>
#       <th>Investigator or Source</th>
#       <td>19438</td>
#     </tr>
#     <tr>
#       <th>pdf</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>href formula</th>
#       <td>19422</td>
#     </tr>
#     <tr>
#       <th>href</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Case Number.1</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Case Number.2</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>original order</th>
#       <td>19414</td>
#     </tr>
#     <tr>
#       <th>Unnamed: 22</th>
#       <td>25722</td>
#     </tr>
#     <tr>
#       <th>Unnamed: 23</th>
#       <td>25721</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Number of Duplicates</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>True</th>
#       <td>19411</td>
#     </tr>
#     <tr>
#       <th>False</th>
#       <td>6312</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# # Data cleaning

# %%
# We have to get rid of all unnecessary columns

filtered_sharks = sharks.drop(["Case Number", "Area", "pdf", "href formula", "Name", "href", "Case Number.1", "Case Number.2", "original order", "Unnamed: 22", "Unnamed: 23", "Investigator or Source"], axis = 1, inplace=False)

list(filtered_sharks.columns)
# Out:
# ['Date',
#  'Year',
#  'Type',
#  'Country',
#  'Location',
#  'Activity',
#  'Sex ',
#  'Age',
#  'Injury',
#  'Fatal (Y/N)',
#  'Time',
#  'Species ']

# %%
# It is useful to rewrite all column names in the correct format (deleting spaces, etc.)

sharks_fil_ren = filtered_sharks.rename(columns = {"Sex ":"Sex", "Species ":"Species"}, inplace = False)

list(sharks_fil_ren.columns)
# Out:
# ['Date',
#  'Year',
#  'Type',
#  'Country',
#  'Location',
#  'Activity',
#  'Sex',
#  'Age',
#  'Injury',
#  'Fatal (Y/N)',
#  'Time',
#  'Species']

# %%
# It's time to delete all the Null and NaN values

sharks_nona = sharks_fil_ren.dropna(axis = 0, how="all", inplace=False)
print(f"The shape is now {sharks_nona.shape}")

display_errors(sharks_nona)
display_side_by_side(sharks_nona.sample(5))
# Out:
# The shape is now (6302, 12)
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of NAs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>540</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>544</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>565</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>2831</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>539</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>3354</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>2838</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of Nuls</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>540</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>544</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>565</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>2831</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>539</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>3354</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>2838</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Number of Duplicates</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>6295</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;"></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Year</th>
#       <th>Type</th>
#       <th>Country</th>
#       <th>Location</th>
#       <th>Activity</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>Injury</th>
#       <th>Fatal (Y/N)</th>
#       <th>Time</th>
#       <th>Species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>750</th>
#       <td>28-Aug-2012</td>
#       <td>2012.0</td>
#       <td>Unprovoked</td>
#       <td>AUSTRALIA</td>
#       <td>Red Bluff near Quobba Station</td>
#       <td>Surfing</td>
#       <td>M</td>
#       <td>34</td>
#       <td>Lacerations to torso and arm</td>
#       <td>N</td>
#       <td>15h30</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2203</th>
#       <td>25-Jan-1998</td>
#       <td>1998.0</td>
#       <td>Unprovoked</td>
#       <td>REUNION</td>
#       <td>NaN</td>
#       <td>Bathing</td>
#       <td>M</td>
#       <td>NaN</td>
#       <td>FATAL</td>
#       <td>Y</td>
#       <td>Mid afternoon</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5143</th>
#       <td>23-Oct-1926</td>
#       <td>1926.0</td>
#       <td>Sea Disaster</td>
#       <td>BERMUDA</td>
#       <td>18 miles southwest of Bermuda</td>
#       <td>British patrol boat 1250-ton HMS  Valerian foundered in a hurricane</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Of 104 people in the water, only 20 survived. 84 people were lost, many to sharks. Sharks 2 pulled crew off life rafts</td>
#       <td>N</td>
#       <td>01h30</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3271</th>
#       <td>04-Apr-1974</td>
#       <td>1974.0</td>
#       <td>Unprovoked</td>
#       <td>SOUTH AFRICA</td>
#       <td>Inyoni Rocks, Amanzimtoti</td>
#       <td>Surfing</td>
#       <td>M</td>
#       <td>17</td>
#       <td>Right foot lacerated</td>
#       <td>N</td>
#       <td>16h30</td>
#       <td>Juvenile dusky shark</td>
#     </tr>
#     <tr>
#       <th>2531</th>
#       <td>01-Oct-1992</td>
#       <td>1992.0</td>
#       <td>Unprovoked</td>
#       <td>AUSTRALIA</td>
#       <td>North Point Beach, Moreton Island</td>
#       <td>Surfing</td>
#       <td>M</td>
#       <td>28</td>
#       <td>FATAL</td>
#       <td>Y</td>
#       <td>14h30</td>
#       <td>4.2 m white shark</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %%
# After that, let's implement a listwise deletion of the rest of the missing values.
# Own criteria: if NaN values > 90 % of the total rows, delete those rows.

sharks_nona_2 = sharks_nona.dropna(axis=0, thresh=int((90/100)*sharks_nona.shape[1] + 1))
      
display_errors(sharks_nona_2)
print(f"The shape is now {sharks_nona_2.shape}")
display(sharks_nona_2.sample(6))

"""Looking good. No duplicates and NaN are significantly reduced. It's obvious that I still have a lot of NaNs, but removing
them only leads to ignoring a lot of data, useful for further investigations"""
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of NAs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>231</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>453</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>731</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of Nuls</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>231</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>453</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>731</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Number of Duplicates</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>2975</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>
# The shape is now (2975, 12)
#              Date    Year        Type    Country  \
# 3078  05-Jan-1980  1980.0  Unprovoked      CHILE
# 3598  28-Dec-1965  1965.0  Unprovoked  AUSTRALIA
# 2154  02-Nov-1998  1998.0    Provoked      JAPAN
# 1341  25-Aug-2007  2007.0  Unprovoked        USA
# 1958  12-Apr-2001  2001.0  Unprovoked        USA
# 3431     Jun-1969  1969.0  Unprovoked        USA
#
#                               Location  \
# 3078          Punta Negra, Pichidangui
# 3598    Bathurst Reef, Rottnest Island
# 2154             460 miles off Iwakuni
# 1341  New Smyrna Beach, Volusia County
# 1958  New Smyrna Beach, Volusia County
# 3431                   Sarasota County
#
#                                            Activity Sex  Age  \
# 3078                                  Hookah Diving   M  NaN
# 3598  Spearfishing, but standing in knee-deep water   M   40
# 2154                               Fishing for tuna   M   52
# 1341                                        Surfing   M   27
# 1958                                  Body boarding   M   12
# 3431                                         Wading   M    8
#
#                                                  Injury Fatal (Y/N)     Time  \
# 3078                                            FATAL             Y    11h00
# 3598                            Thigh & swim fin bitten           N      NaN
# 2154  PROVOKED INCIDENT    Knee bitten by shark trap...           N      NaN
# 1341                         6 lacerations to left hand           N  Morning
# 1958                             Foot & ankle lacerated           N    12h34
# 3431                                          No injury           N    20h00
#
#                                             Species
# 3078                                    White shark
# 3598                        1.8 m [6'] carpet shark
# 2154                                       6' shark
# 1341                                       3' shark
# 1958  Possibly a juvenile blacktip or spinner shark
# 3431                                            NaN
# "Looking good. No duplicates and NaN are significantly reduced. It's obvious that I still have a lot of NaNs, but removing\nthem only leads to ignoring a lot of data, useful for further investigations"

# %%
#Cleaning a bit more Year column (we don't want them to be a float).

sharks_nona_2["Year"] = sharks_nona_2["Year"].astype(int)
#sharks_nona_2.loc[:, "Year"].astype(int)

display(sharks_nona_2.sample())

"""Nice"""
# Out:
#              Date  Year        Type Country              Location  \
# 2840  12-Oct-1985  1985  Unprovoked     USA  Barbers Point, O'ahu
#
#                                              Activity Sex Age  \
# 2840  Floating on inner tube after diving for lobster   M  24
#
#                   Injury Fatal (Y/N) Time                          Species
# 2840  Left arm lacerated           N  NaN  1.8 m to 2.4 m [6' to 8'] shark
# 'Nice'

# %%
# We don't need the day and year in the "Date" column

sharks_nona_2["Date"] = sharks_nona_2["Date"].str.extract(r"-(\w{3})-")

sharks_nona_2 = sharks_nona_2.rename(columns = {"Date": "Month"}, inplace=False)

sharks_nona_2 = sharks_nona_2.dropna(subset=["Month"], how="any", axis=0, inplace=False)

sharks_nona_2.sample()
# Out:
#      Month  Year        Type       Country     Location  \
# 3672   Jul  1964  Unprovoked  SOUTH AFRICA  Island Rock
#
#                                   Activity Sex Age  \
# 3672  Searching for remains of  Dr. Marais   M  30
#
#                                                  Injury Fatal (Y/N) Time  \
# 3672  No injury, shark charged & impaled itself on s...           N  NaN
#
#             Species
# 3672  Zambesi shark

# %%
# We can filter the species by the proper name of the shark, everything else is redundant

sharks_nona_2["Species"] = sharks_nona_2["Species"].str.extract(r"([A-Z|a-z]{2,}\sshark)")
display_errors(sharks_nona_2)
sharks_nona_2.sample(5)
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of NAs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Month</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>221</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>78</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>1447</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of Nuls</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Month</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>221</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>78</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>1447</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Number of Duplicates</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>2874</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>
#      Month  Year        Type Country  \
# 436    Apr  2015  Unprovoked     USA
# 1847   Jun  2002  Unprovoked     USA
# 1774   May  2003  Unprovoked     USA
# 1824   Sep  2002    Provoked     USA
# 2666   Sep  1989  Unprovoked     USA
#
#                                                Location      Activity Sex Age  \
# 436              3 miles off Jupiter, Palm Beach County  Spearfishing   M  70
# 1847                   New Smyrna Beach, Volusia County      Swimming   F  11
# 1774  Between Magic Sands Beach and Kahaluu Beach on...      Swimming   M  20
# 1824                           Key Largo, Monroe County       Fishing   M
# 2666                                 Salvo, Dare County       Surfing   M  31
#
#                                       Injury Fatal (Y/N)       Time  \
# 436                 Injuries to head & torso           N  Afternoon
# 1847    Small lacerations on right lower leg           N      14h25
# 1774                Right calf & heel bitten           N      11h45
# 1824  Left thumb lacerated PROVOKED INCIDENT           N  Afternoon
# 2666                               Non-fatal           N        NaN
#
#              Species
# 436       Bull shark
# 1847             NaN
# 1774      reef shark
# 1824  blacktip shark
# 2666   Sandbar shark

# %%
#Renaming

sharks_cl1 = sharks_nona_2

# %%
# We can capitalize the shark types
sharks_cl1["Species"] = sharks_cl1["Species"].str.capitalize()

# %%
sharks_cl1.sample(3)
# Out:
#      Month  Year          Type Country  \
# 1900   Sep  2001       Invalid     USA
# 3094   Jun  1979  Sea Disaster     USA
# 938    Mar  2011    Unprovoked    FIJI
#
#                                        Location  \
# 1900  2 miles off Pompano Beach, Broward County
# 3094                10 miles off Cape Canaveral
# 938                                   Nukudamu
#
#                                                Activity Sex Age  \
# 1900                           Wreck / Technical diving   M  42
# 3094  Floating with life preserver after his boat fo...   M  56
# 938                                    Diving / fishing   M  30
#
#                                                  Injury Fatal (Y/N)     Time  \
# 1900                     FATAL or drowning & scavenging           Y    13h20
# 3094                                 Lacerations to leg           N  Morning
# 938   Left forearm severely bitten, surgically amput...           N    16h00
#
#      Species
# 1900     NaN
# 3094     NaN
# 938      NaN

# %%
sharks_cl1.reset_index()

sharks_cl1.head()
# Out:
#   Month  Year        Type Country  \
# 0   Jun  2018     Boating     USA
# 1   Jun  2018  Unprovoked     USA
# 2   Jun  2018     Invalid     USA
# 6   Jun  2018  Unprovoked  BRAZIL
# 7   May  2018  Unprovoked     USA
#
#                                             Location  Activity Sex Age  \
# 0                        Oceanside, San Diego County  Paddling   F  57
# 1                     St. Simon Island, Glynn County  Standing   F  11
# 2                                       Habush, Oahu   Surfing   M  48
# 6                              Piedade Beach, Recife  Swimming   M  18
# 7  Lighhouse Point Park, Ponce Inlet, Volusia County   Fishing   M  52
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 6                                              FATAL           Y
# 7            Minor injury to foot. PROVOKED INCIDENT           N
#
#              Time      Species
# 0           18h00  White shark
# 1   14h00  -15h00          NaN
# 2           07h45          NaN
# 6  Late afternoon  Tiger shark
# 7             NaN  Lemon shark

# %% [markdown]
# # Cleaned dataset

# %% [markdown]
# At this point, I consider the table ready to be analyzed properly be taking the right columns. Data extraction & visualization will be taken place in a separated notebook

# %%
sharks_cl1.to_csv("../data/attacks_cleaned.csv", index = False)

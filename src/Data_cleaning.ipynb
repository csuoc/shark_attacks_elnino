# %% [markdown]
# # Importing the necessary tools

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np
import re
import seaborn as sns
from IPython.display import display_html
from itertools import chain,cycle

# %%
# Importing the file.csv

sharks = pd.read_csv("../data/attacks.csv", header = 0, encoding= 'unicode_escape')

# %%
# This is a function to display multiple tables in the same row

def display_side_by_side(*args,titles=cycle([''])):
    html_str=''
    for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        html_str+=f'<h2 style="text-align: center;">{title}</h2>'
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+='</td></th>'
    display_html(html_str,raw=True)

# %% [markdown]
# # First info about the dataset: shape, columns...

# %%
# First info

print(f"The shape is now {sharks.shape}")
# Out:
# The shape is now (25723, 24)

# %%
# Displaying Describe and Head tables
display_side_by_side(sharks.describe(), pd.DataFrame(sharks.columns),sharks.sample(6), titles=['Describe', "Column names", 'Head'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Describe</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>original order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>6300.000000</td>
#       <td>6309.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>1927.272381</td>
#       <td>3155.999683</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>281.116308</td>
#       <td>1821.396206</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.000000</td>
#       <td>2.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>1942.000000</td>
#       <td>1579.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>1977.000000</td>
#       <td>3156.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>2005.000000</td>
#       <td>4733.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>2018.000000</td>
#       <td>6310.000000</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Column names</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Case Number</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Date</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Year</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Type</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Country</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Area</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Location</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Activity</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Name</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Sex</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Age</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Injury</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Fatal (Y/N)</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Time</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Species</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Investigator or Source</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>pdf</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>href formula</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>href</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Case Number.1</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Case Number.2</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>original order</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Unnamed: 22</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Unnamed: 23</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Head</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Case Number</th>
#       <th>Date</th>
#       <th>Year</th>
#       <th>Type</th>
#       <th>Country</th>
#       <th>Area</th>
#       <th>Location</th>
#       <th>Activity</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>Injury</th>
#       <th>Fatal (Y/N)</th>
#       <th>Time</th>
#       <th>Species</th>
#       <th>Investigator or Source</th>
#       <th>pdf</th>
#       <th>href formula</th>
#       <th>href</th>
#       <th>Case Number.1</th>
#       <th>Case Number.2</th>
#       <th>original order</th>
#       <th>Unnamed: 22</th>
#       <th>Unnamed: 23</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>19502</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>14747</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5719</th>
#       <td>1889.01.31.R</td>
#       <td>Reported 31-Jan-1889</td>
#       <td>1889.0</td>
#       <td>Provoked</td>
#       <td>USA</td>
#       <td>Florida</td>
#       <td>Hillsborough Bay</td>
#       <td>Fishing</td>
#       <td>rowboat,</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>No injury to occupants. Gaffed shark capsized boat PROVOKED INCIDENT</td>
#       <td>N</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Timaru Herald, 1/31/1889</td>
#       <td>1889.01.31.R-Florida.pdf</td>
#       <td>http://sharkattackfile.net/spreadsheets/pdf_directory/1889.01.31.R-Florida.pdf</td>
#       <td>http://sharkattackfile.net/spreadsheets/pdf_directory/1889.01.31.R-Florida.pdf</td>
#       <td>1889.01.31.R</td>
#       <td>1889.01.31.R</td>
#       <td>584.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>16409</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>23531</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>13352</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %%
#Custom function to display errors

def display_errors(df):
    
    total_nas = pd.DataFrame(df.isna().sum())
    total_null = pd.DataFrame(df.isnull().sum())
    duplicated = pd.DataFrame(df.duplicated().value_counts())


    return display_side_by_side(total_nas, total_null, duplicated, titles=['Sum of NAs', "Sum of Nuls", "Number of Duplicates"])

# %%
# Display of the errors

display_errors(sharks)
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of NAs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Case Number</th>
#       <td>17021</td>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>19423</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>19425</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>19471</td>
#     </tr>
#     <tr>
#       <th>Area</th>
#       <td>19876</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>19961</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>19965</td>
#     </tr>
#     <tr>
#       <th>Name</th>
#       <td>19631</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>19986</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>22252</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>19449</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>19960</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>22775</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>22259</td>
#     </tr>
#     <tr>
#       <th>Investigator or Source</th>
#       <td>19438</td>
#     </tr>
#     <tr>
#       <th>pdf</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>href formula</th>
#       <td>19422</td>
#     </tr>
#     <tr>
#       <th>href</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Case Number.1</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Case Number.2</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>original order</th>
#       <td>19414</td>
#     </tr>
#     <tr>
#       <th>Unnamed: 22</th>
#       <td>25722</td>
#     </tr>
#     <tr>
#       <th>Unnamed: 23</th>
#       <td>25721</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of Nuls</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Case Number</th>
#       <td>17021</td>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>19423</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>19425</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>19471</td>
#     </tr>
#     <tr>
#       <th>Area</th>
#       <td>19876</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>19961</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>19965</td>
#     </tr>
#     <tr>
#       <th>Name</th>
#       <td>19631</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>19986</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>22252</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>19449</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>19960</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>22775</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>22259</td>
#     </tr>
#     <tr>
#       <th>Investigator or Source</th>
#       <td>19438</td>
#     </tr>
#     <tr>
#       <th>pdf</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>href formula</th>
#       <td>19422</td>
#     </tr>
#     <tr>
#       <th>href</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Case Number.1</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Case Number.2</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>original order</th>
#       <td>19414</td>
#     </tr>
#     <tr>
#       <th>Unnamed: 22</th>
#       <td>25722</td>
#     </tr>
#     <tr>
#       <th>Unnamed: 23</th>
#       <td>25721</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Number of Duplicates</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>True</th>
#       <td>19411</td>
#     </tr>
#     <tr>
#       <th>False</th>
#       <td>6312</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# # Data cleaning

# %%
# We have to get rid of all unnecessary columns

filtered_sharks = sharks.drop(["Case Number", "Area", "pdf", "href formula", "Name", "href", "Case Number.1", "Case Number.2", "original order", "Unnamed: 22", "Unnamed: 23", "Investigator or Source"], axis = 1, inplace=False)

list(filtered_sharks.columns)
# Out:
# ['Date',
#  'Year',
#  'Type',
#  'Country',
#  'Location',
#  'Activity',
#  'Sex ',
#  'Age',
#  'Injury',
#  'Fatal (Y/N)',
#  'Time',
#  'Species ']

# %%
# It is useful to rewrite all column names in the correct format (deleting spaces, etc.)

sharks_fil_ren = filtered_sharks.rename(columns = {"Sex ":"Sex", "Species ":"Species"}, inplace = False)

list(sharks_fil_ren.columns)
# Out:
# ['Date',
#  'Year',
#  'Type',
#  'Country',
#  'Location',
#  'Activity',
#  'Sex',
#  'Age',
#  'Injury',
#  'Fatal (Y/N)',
#  'Time',
#  'Species']

# %%
# It's time to delete all the Null and NaN values

sharks_nona = sharks_fil_ren.dropna(axis = 0, how="all", inplace=False)
print(f"The shape is now {sharks_nona.shape}")

display_errors(sharks_nona)
display_side_by_side(sharks_nona.sample(5))
# Out:
# The shape is now (6302, 12)
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of NAs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>540</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>544</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>565</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>2831</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>539</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>3354</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>2838</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of Nuls</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>540</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>544</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>565</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>2831</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>539</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>3354</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>2838</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Number of Duplicates</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>6295</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;"></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Year</th>
#       <th>Type</th>
#       <th>Country</th>
#       <th>Location</th>
#       <th>Activity</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>Injury</th>
#       <th>Fatal (Y/N)</th>
#       <th>Time</th>
#       <th>Species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3945</th>
#       <td>01-Dec-1960</td>
#       <td>1960.0</td>
#       <td>Unprovoked</td>
#       <td>AUSTRALIA</td>
#       <td>Colledge's Crossing, Brisbane River</td>
#       <td>Fishing</td>
#       <td>M</td>
#       <td>NaN</td>
#       <td>Bitten &amp; survived</td>
#       <td>N</td>
#       <td>NaN</td>
#       <td>Bull shark, 1m</td>
#     </tr>
#     <tr>
#       <th>2913</th>
#       <td>21-Dec-1983</td>
#       <td>1983.0</td>
#       <td>Unprovoked</td>
#       <td>SOUTH AFRICA</td>
#       <td>Nahoon</td>
#       <td>Swimming</td>
#       <td>M</td>
#       <td>47</td>
#       <td>Shin lacerated</td>
#       <td>N</td>
#       <td>08h15</td>
#       <td>Raggedtooth shark, &gt;1 m</td>
#     </tr>
#     <tr>
#       <th>819</th>
#       <td>06-Feb-2012</td>
#       <td>2012.0</td>
#       <td>Unprovoked</td>
#       <td>AUSTRALIA</td>
#       <td>Wurtulla</td>
#       <td>Surfing</td>
#       <td>M</td>
#       <td>29</td>
#       <td>No injury, but fin lost from surfboard</td>
#       <td>N</td>
#       <td>12h00</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3365</th>
#       <td>6-Apr-1971</td>
#       <td>1971.0</td>
#       <td>Unprovoked</td>
#       <td>MEXICO</td>
#       <td>Copacabana Beach, Acapulco</td>
#       <td>Surfing</td>
#       <td>M</td>
#       <td>19</td>
#       <td>FATAL, left thigh bitten</td>
#       <td>Y</td>
#       <td>11h00</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3904</th>
#       <td>17-Apr-1961</td>
#       <td>1961.0</td>
#       <td>Provoked</td>
#       <td>SOUTH AFRICA</td>
#       <td>Port Elizabeth Oceanarium</td>
#       <td>Diving</td>
#       <td>M</td>
#       <td>NaN</td>
#       <td>Shark bit swimfin after diver kicked shark PROVOKED INCIDENT</td>
#       <td>N</td>
#       <td>NaN</td>
#       <td>2 m  "yellow belly" captive shark. Shark destroyed by aquarium staff next day</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %%
# After that, let's implement a listwise deletion of the rest of the missing values.
# Own criteria: if NaN values > 90 % of the total rows, delete those rows.

sharks_nona_2 = sharks_nona.dropna(axis=0, thresh=int((90/100)*sharks_nona.shape[1] + 1))
      
display_errors(sharks_nona_2)
print(f"The shape is now {sharks_nona_2.shape}")
display(sharks_nona_2.sample(6))

"""Looking good. No duplicates and NaN are significantly reduced. It's obvious that I still have a lot of NaNs, but removing
them only leads to ignoring a lot of data, useful for further investigations"""
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of NAs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>231</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>453</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>731</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of Nuls</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>231</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>453</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>731</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Number of Duplicates</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>2975</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>
# The shape is now (2975, 12)
#                       Date    Year        Type       Country  \
# 3649           25-Dec-1964  1964.0  Unprovoked  SOUTH AFRICA
# 848   Reported 28-Oct-2011  2011.0  Unprovoked      SCOTLAND
# 1206           07-Sep-2008  2008.0  Unprovoked     AUSTRALIA
# 526            27-Jul-2014  2014.0  Unprovoked           USA
# 1487           19-Apr-2006  2006.0  Unprovoked           USA
# 3526     13 or 30-May-1967  1967.0    Provoked     AUSTRALIA
#
#                             Location  Activity Sex   Age  \
# 3649                     Port Alfred  Swimming   M    19
# 848                         Spey Bay   Surfing   M    26
# 1206         Clarks Beach, Byron Bay   Surfing   M    51
# 526   Sunset Beach, Brunswick County  Swimming   M  Teen
# 1487   Daytona Beach, Volusia County  Standing   F    13
# 3526                    Outer Harbor       NaN   M    30
#
#                                                  Injury Fatal (Y/N)     Time  \
# 3649                       Hand, ankle & calf lacerated           N    17h00
# 848               No injury, shark bumped leg & board.            N      NaN
# 1206  Shark became tangled in his surfboard leash. T...           N    12h00
# 526                                    Left foot bitten           N      NaN
# 1487  3 tiny punctures & small lacerations on right ...           N    15h00
# 3526  Thigh abraded & lacerated Recorded as PROVOKED...           N  Morning
#
#                             Species
# 3649             Raggedtooth shark
# 848                 8' to 10' shark
# 1206                      3 m shark
# 526   Possibly juvenile tiger shark
# 1487                            NaN
# 3526            Bronze whaler shark
# "Looking good. No duplicates and NaN are significantly reduced. It's obvious that I still have a lot of NaNs, but removing\nthem only leads to ignoring a lot of data, useful for further investigations"

# %%
#Cleaning a bit more Year column (we don't want them to be a float).

sharks_nona_2["Year"] = sharks_nona_2["Year"].astype(int)
#sharks_nona_2.loc[:, "Year"].astype(int)

display(sharks_nona_2.sample())

"""Nice"""
# Out:
#              Date  Year        Type Country                   Location  \
# 2137  03-Feb-1999  1999  Unprovoked     USA  Hobe Sound, Martin County
#
#      Activity Sex Age            Injury Fatal (Y/N)   Time        Species
# 2137  Surfing   M  25  Left hand bitten           N  15h30  Spinner shark
# 'Nice'

# %%
# We don't need the day and year in the "Date" column

sharks_nona_2["Date"] = sharks_nona_2["Date"].str.extract(r"-(\w{3})-")

sharks_nona_2 = sharks_nona_2.rename(columns = {"Date": "Month"}, inplace=False)

sharks_nona_2.sample(10)
# Out:
#      Month  Year        Type       Country  \
# 5183   Apr  1924  Unprovoked     AUSTRALIA
# 66     Oct  2017  Unprovoked     AUSTRALIA
# 1113   Jul  2009  Unprovoked  SOUTH AFRICA
# 5406   Feb  1910  Unprovoked     AUSTRALIA
# 1731   Oct  2003     Invalid           USA
# 1447   NaN  2006  Unprovoked           USA
# 2254   May  1997  Unprovoked           USA
# 1552   Sep  2005  Unprovoked     AUSTRALIA
# 3463   Aug  1968  Unprovoked      COLUMBIA
# 568    Apr  2014  Unprovoked           USA
#
#                                   Location  \
# 5183                                 Kiama
# 66                            Birubi Point
# 1113               Jogensfontein, Stilbaai
# 5406                               Bunbury
# 1731                           Palm Beach?
# 1447  Masonboro Island, New Hanover County
# 2254         Flagler Beach, Flagler County
# 1552           Fishery Bay, Eyre Peninsula
# 3463                 Makuaka Caño, Taganga
# 568       New Smyrna Beach, Volusia County
#
#                                                Activity Sex   Age  \
# 5183  Fishing, fell in water & swimming strongly to ...   M    20
# 66                                              Surfing   M    31
# 1113                                            Surfing   M    37
# 5406                                       Surf bathing   M   NaN
# 1731               Swimming to shore from boat or kayak   M   NaN
# 1447                                             Wading   F    59
# 2254                                            Surfing   M    12
# 1552                                            Surfing   M    40
# 3463                                   Dynamite fishing   M    18
# 568                                             Surfing   M  teen
#
#                                                  Injury Fatal (Y/N)  \
# 5183                  FATAL, partial remains recovered            Y
# 66                                 Minor injury to foot           N
# 1113                                         Leg bitten           N
# 5406                        Shoulder, back & leg bitten           N
# 1731  Fatal, drowning or scavenging.  Two hours late...           Y
# 1447               Lacerations & punctures to left foot           N
# 2254                                  Left ankle bitten           N
# 1552                   Lacerations to right arm & thigh           N
# 3463                                Lacerations to head           N
# 568                                 Lacerations to foot           N
#
#            Time                                            Species
# 5183  Afternoon                                                NaN
# 66        09h00                               Wobbegong shark, 1 m
# 1113      11h15                                                NaN
# 5406      Night                                   5.5' to 6' shark
# 1731         --  Shark involvement prior to death was not confi...
# 1447      12h00                                                NaN
# 2254      11h00                              Possibly a sand shark
# 1552      15h00                              4 m [13'] white shark
# 3463      10h30                                          2 m shark
# 568       13h30                                                NaN

# %%
#sharks_nona_2.to_csv("../data/attacks_cleaned.csv")

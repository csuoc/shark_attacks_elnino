# %% [markdown]
# # Importing the necessary tools

# %%
import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np
import re
import seaborn as sns
from IPython.display import display_html
from itertools import chain,cycle

# %%
# Importing the file.csv

sharks = pd.read_csv("../data/attacks.csv", header = 0, encoding= 'unicode_escape')

# %%
# This is a function to display multiple tables in the same row

def display_side_by_side(*args,titles=cycle([''])):
    html_str=''
    for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        html_str+=f'<h2 style="text-align: center;">{title}</h2>'
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+='</td></th>'
    display_html(html_str,raw=True)

# %% [markdown]
# # First info about the dataset: shape, columns...

# %%
# First info

print(f"The shape is now {sharks.shape}")
# Out:
# The shape is now (25723, 24)

# %%
# Displaying Describe and Head tables
display_side_by_side(sharks.describe(), pd.DataFrame(sharks.columns),sharks.sample(6), titles=['Describe', "Column names", 'Head'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Describe</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>original order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>6300.000000</td>
#       <td>6309.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>1927.272381</td>
#       <td>3155.999683</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>281.116308</td>
#       <td>1821.396206</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.000000</td>
#       <td>2.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>1942.000000</td>
#       <td>1579.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>1977.000000</td>
#       <td>3156.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>2005.000000</td>
#       <td>4733.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>2018.000000</td>
#       <td>6310.000000</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Column names</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Case Number</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Date</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Year</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Type</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Country</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Area</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Location</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Activity</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Name</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Sex</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Age</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Injury</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Fatal (Y/N)</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Time</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Species</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Investigator or Source</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>pdf</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>href formula</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>href</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Case Number.1</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Case Number.2</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>original order</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Unnamed: 22</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Unnamed: 23</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Head</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Case Number</th>
#       <th>Date</th>
#       <th>Year</th>
#       <th>Type</th>
#       <th>Country</th>
#       <th>Area</th>
#       <th>Location</th>
#       <th>Activity</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>Injury</th>
#       <th>Fatal (Y/N)</th>
#       <th>Time</th>
#       <th>Species</th>
#       <th>Investigator or Source</th>
#       <th>pdf</th>
#       <th>href formula</th>
#       <th>href</th>
#       <th>Case Number.1</th>
#       <th>Case Number.2</th>
#       <th>original order</th>
#       <th>Unnamed: 22</th>
#       <th>Unnamed: 23</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>19461</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>11373</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>17722</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4643</th>
#       <td>1944.08.20</td>
#       <td>20-Aug-1944</td>
#       <td>1944.0</td>
#       <td>Unprovoked</td>
#       <td>SOUTH AFRICA</td>
#       <td>KwaZulu-Natal</td>
#       <td>Margate</td>
#       <td>Swimming</td>
#       <td>Dennis Nissen</td>
#       <td>M</td>
#       <td>19</td>
#       <td>FATAL, body not recovered</td>
#       <td>Y</td>
#       <td>14h00</td>
#       <td>NaN</td>
#       <td>T. Blake, M. Levine, GSAF</td>
#       <td>1944.08.20-Nissen.pdf</td>
#       <td>http://sharkattackfile.net/spreadsheets/pdf_directory/1944.08.20-Nissen.pdf</td>
#       <td>http://sharkattackfile.net/spreadsheets/pdf_directory/1944.08.20-Nissen.pdf</td>
#       <td>1944.08.20</td>
#       <td>1944.08.20</td>
#       <td>1660.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>15266</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>23378</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %%
#Custom function to display errors

def display_errors(df):
    
    total_nas = pd.DataFrame(df.isna().sum())
    total_null = pd.DataFrame(df.isnull().sum())
    duplicated = pd.DataFrame(df.duplicated().value_counts())


    return display_side_by_side(total_nas, total_null, duplicated, titles=['Sum of NAs', "Sum of Nuls", "Number of Duplicates"])

# %%
# Display of the errors

display_errors(sharks)
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of NAs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Case Number</th>
#       <td>17021</td>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>19423</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>19425</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>19471</td>
#     </tr>
#     <tr>
#       <th>Area</th>
#       <td>19876</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>19961</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>19965</td>
#     </tr>
#     <tr>
#       <th>Name</th>
#       <td>19631</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>19986</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>22252</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>19449</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>19960</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>22775</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>22259</td>
#     </tr>
#     <tr>
#       <th>Investigator or Source</th>
#       <td>19438</td>
#     </tr>
#     <tr>
#       <th>pdf</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>href formula</th>
#       <td>19422</td>
#     </tr>
#     <tr>
#       <th>href</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Case Number.1</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Case Number.2</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>original order</th>
#       <td>19414</td>
#     </tr>
#     <tr>
#       <th>Unnamed: 22</th>
#       <td>25722</td>
#     </tr>
#     <tr>
#       <th>Unnamed: 23</th>
#       <td>25721</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of Nuls</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Case Number</th>
#       <td>17021</td>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>19423</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>19425</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>19471</td>
#     </tr>
#     <tr>
#       <th>Area</th>
#       <td>19876</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>19961</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>19965</td>
#     </tr>
#     <tr>
#       <th>Name</th>
#       <td>19631</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>19986</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>22252</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>19449</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>19960</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>22775</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>22259</td>
#     </tr>
#     <tr>
#       <th>Investigator or Source</th>
#       <td>19438</td>
#     </tr>
#     <tr>
#       <th>pdf</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>href formula</th>
#       <td>19422</td>
#     </tr>
#     <tr>
#       <th>href</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Case Number.1</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>Case Number.2</th>
#       <td>19421</td>
#     </tr>
#     <tr>
#       <th>original order</th>
#       <td>19414</td>
#     </tr>
#     <tr>
#       <th>Unnamed: 22</th>
#       <td>25722</td>
#     </tr>
#     <tr>
#       <th>Unnamed: 23</th>
#       <td>25721</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Number of Duplicates</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>True</th>
#       <td>19411</td>
#     </tr>
#     <tr>
#       <th>False</th>
#       <td>6312</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ## Remove unnecessary columns

# %%
# We have to get rid of all unnecessary columns

filtered_sharks = sharks.drop(["Case Number", "Area", "pdf", "href formula", "Name", "href", "Case Number.1", "Case Number.2", "original order", "Unnamed: 22", "Unnamed: 23", "Investigator or Source"], axis = 1, inplace=False)

list(filtered_sharks.columns)
# Out:
# ['Date',
#  'Year',
#  'Type',
#  'Country',
#  'Location',
#  'Activity',
#  'Sex ',
#  'Age',
#  'Injury',
#  'Fatal (Y/N)',
#  'Time',
#  'Species ']

# %%
# It is useful to rewrite all column names in the correct format (deleting spaces, etc.)

sharks_fil_ren = filtered_sharks.rename(columns = {"Sex ":"Sex", "Species ":"Species"}, inplace = False)

list(sharks_fil_ren.columns)
# Out:
# ['Date',
#  'Year',
#  'Type',
#  'Country',
#  'Location',
#  'Activity',
#  'Sex',
#  'Age',
#  'Injury',
#  'Fatal (Y/N)',
#  'Time',
#  'Species']

# %% [markdown]
# ## Deleting Null and NaNs

# %%
# It's time to delete all the Null and NaN values

sharks_nona = sharks_fil_ren.dropna(axis = 0, how="all", inplace=False)
print(f"The shape is now {sharks_nona.shape}")

display_errors(sharks_nona)
display_side_by_side(sharks_nona.sample(5))
# Out:
# The shape is now (6302, 12)
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of NAs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>540</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>544</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>565</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>2831</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>539</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>3354</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>2838</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of Nuls</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>540</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>544</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>565</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>2831</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>539</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>3354</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>2838</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Number of Duplicates</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>6295</td>
#     </tr>
#     <tr>
#       <th>True</th>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;"></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Year</th>
#       <th>Type</th>
#       <th>Country</th>
#       <th>Location</th>
#       <th>Activity</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>Injury</th>
#       <th>Fatal (Y/N)</th>
#       <th>Time</th>
#       <th>Species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>450</th>
#       <td>05-Feb-2015</td>
#       <td>2015.0</td>
#       <td>Unprovoked</td>
#       <td>AUSTRALIA</td>
#       <td>Mereweather Beach</td>
#       <td>Bodysurfing</td>
#       <td>M</td>
#       <td>NaN</td>
#       <td>5 minor puncture wounds to lower left leg</td>
#       <td>N</td>
#       <td>NaN</td>
#       <td>1.8 m shark</td>
#     </tr>
#     <tr>
#       <th>4921</th>
#       <td>24-Jan-1935</td>
#       <td>1935.0</td>
#       <td>Unprovoked</td>
#       <td>AUSTRALIA</td>
#       <td>Off Ben Buckler, near Sydney</td>
#       <td>Fishing</td>
#       <td>M</td>
#       <td>NaN</td>
#       <td>No injury, sleeve ripped</td>
#       <td>N</td>
#       <td>NaN</td>
#       <td>Tiger shark, 12'</td>
#     </tr>
#     <tr>
#       <th>1483</th>
#       <td>04-May-2006</td>
#       <td>2006.0</td>
#       <td>Unprovoked</td>
#       <td>USA</td>
#       <td>Hutchinson Island, St. Lucie County</td>
#       <td>Swimming</td>
#       <td>F</td>
#       <td>20s</td>
#       <td>2 lacerations on lower right leg</td>
#       <td>N</td>
#       <td>16h30</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>6241</th>
#       <td>1960s</td>
#       <td>0.0</td>
#       <td>Unprovoked</td>
#       <td>IRAQ</td>
#       <td>Shatt-al-Arab River</td>
#       <td>Fishing from a small boat &amp; put his hand in the water while holding a dead fish</td>
#       <td>M</td>
#       <td>25</td>
#       <td>Right hand severed</td>
#       <td>N</td>
#       <td>Afternoon</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3133</th>
#       <td>31-Dec-1977</td>
#       <td>1977.0</td>
#       <td>Sea Disaster</td>
#       <td>USA</td>
#       <td>2 miles off Keahole Airport</td>
#       <td>Swimming, after single-engine aircraft went down in the sea</td>
#       <td>M</td>
#       <td>49</td>
#       <td>Feet lacerated</td>
#       <td>N</td>
#       <td>Night</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %%
# After that, let's implement a listwise deletion of the rest of the missing values.
# Own criteria: if NaN values > 90 % of the total rows, delete those rows.

sharks_nona_2 = sharks_nona.dropna(axis=0, thresh=int((90/100)*sharks_nona.shape[1] + 1))
      
display_errors(sharks_nona_2)
print(f"The shape is now {sharks_nona_2.shape}")
display(sharks_nona_2.sample(6))

"""Looking good. No duplicates and NaN are significantly reduced. It's obvious that I still have a lot of NaNs, but removing
them only leads to ignoring a lot of data, useful for further investigations"""
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of NAs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>231</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>453</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>731</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of Nuls</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Date</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>231</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>453</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>731</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Number of Duplicates</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>2975</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>
# The shape is now (2975, 12)
#              Date    Year        Type       Country  \
# 959   11-Dec-2010  2010.0  Unprovoked           USA
# 2175  01-Aug-1998  1998.0  Unprovoked  SOUTH AFRICA
# 1101  01-Aug-2009  2009.0  Unprovoked           USA
# 44    11-Feb-2018  2018.0     Invalid        BRAZIL
# 3458  15-Sep-1968  1968.0  Unprovoked   NEW ZEALAND
# 757   31-Jul-2012  2012.0  Unprovoked           USA
#
#                                Location       Activity Sex Age  \
# 959                   Tavares Bay, Maui        Surfing   M  46
# 2175                        Pringle Bay   Spearfishing   M  24
# 1101        Curlew Island, Breton Sound   Wade Fishing   M  56
# 44                       Espirito Santo  Cleaning fish   F  46
# 3458                       Otago Harbor   Spearfishing   M  24
# 757   Topanga Beach, Los Angeles County        Surfing   M  17
#
#                                                  Injury Fatal (Y/N)   Time  \
# 959                           Lacerations to right foot           N  13h51
# 2175                                         Leg bitten           N  13h00
# 1101                          Right ankle & foot bitten           N  10h00
# 44                  Lacerations to 4 toes of right foot           N    NaN
# 3458   FATAL, left leg bitten, femoral artery severed             Y  10h15
# 757   No injury, surfer knocked off board when shark...           N  06h45
#
#                                                 Species
# 959                                                 NaN
# 2175                           White shark, 4.9 m [16']
# 1101                                        Bull shark?
# 44        Injury believed caused by an eel, not a shark
# 3458  White shark, 4.3 m [14'], (tooth fragment reco...
# 757                                                 NaN
# "Looking good. No duplicates and NaN are significantly reduced. It's obvious that I still have a lot of NaNs, but removing\nthem only leads to ignoring a lot of data, useful for further investigations"

# %% [markdown]
# ## Cleaning the Year column

# %%
#Cleaning a bit more Year column (we don't want them to be a float).

sharks_nona_2["Year"] = sharks_nona_2["Year"].astype(int)
#sharks_nona_2.loc[:, "Year"].astype(int)

display(sharks_nona_2.sample())

"""Nice"""
# Out:
#              Date  Year        Type Country                     Location  \
# 2165  14-Sep-1998  1998  Unprovoked     USA  Stuart Beach, Martin County
#
#      Activity Sex Age             Injury Fatal (Y/N) Time           Species
# 2165  Surfing   M  28  Right foot bitten           N  NaN  1.8 m [6'] shark
# 'Nice'

# %%
# We don't need the day and year in the "Date" column

sharks_nona_2["Date"] = sharks_nona_2["Date"].str.extract(r"-(\w{3})-")

sharks_nona_2 = sharks_nona_2.rename(columns = {"Date": "Month"}, inplace=False)

sharks_nona_2 = sharks_nona_2.dropna(subset=["Month"], how="any", axis=0, inplace=False)

sharks_nona_2.sample()
# Out:
#    Month  Year        Type Country    Location Activity Sex  Age  \
# 80   Sep  2017  Unprovoked     USA  Fort Worth  Surfing   M  NaN
#
#                      Injury Fatal (Y/N)   Time         Species
# 80  Laceration to upper arm           N  14h00  4' to 5' shark

# %% [markdown]
# ## Cleaning the Species column

# %%
list(sharks_nona_2["Species"])
# Out:
# ['White shark',
#  nan,
#  nan,
#  'Tiger shark',
#  "Lemon shark, 3'",
#  "Bull shark, 6'",
#  nan,
#  'Grey reef shark',
#  nan,
#  'Invalid incident',
#  'Shark involvement not confirmed',
#  'Tiger shark',
#  'Questionable',
#  '3 m shark',
#  'White shark, 3.5 m',
#  'Tiger shark',
#  'White shark, 2.5 m',
#  "6' shark",
#  'Juvenile bull shark',
#  nan,
#  'Tiger shark',
#  'Shark involvement not confirmed',
#  'Bull shark',
#  'White shark',
#  "Tiger shark, 12'",
#  'Wobbegong shark',
#  '3.5 m shark',
#  '1.8 m shark',
#  'Blacktip shark',
#  'Juvenile white shark,  2.7 to 3.2 m',
#  nan,
#  'Bull shark, 2 m',
#  'Possibly a wobbegong',
#  'Injury believed caused by an eel, not a shark',
#  'Galapagos shark?',
#  '2m shark',
#  'Bull shark',
#  'Bull shark, 3 m ',
#  'Grey reef shark. 2 m',
#  'White shark, 3.5 m',
#  'small shark',
#  'Tiger shark',
#  nan,
#  'Juvenile nurse shark',
#  'Tiger shark, female',
#  'Tiger shark, female',
#  'White shark, 4.6 m',
#  nan,
#  '2 m shark',
#  'Tiger shark',
#  'Cookiecutter shark',
#  'Wobbegong shark, 1 m',
#  nan,
#  nan,
#  'White shark, 4.5 m',
#  '2 m shark',
#  'Spinner shark, 4 to 5 feet',
#  'Tiger shark, 8 to 10 feet',
#  "8' shark",
#  "5' shark",
#  'White shark, 3.5 m',
#  'Questionable',
#  "4' to 5' shark",
#  'Porbeagle, 1.5 m',
#  nan,
#  "5' to 6' shark",
#  'White shark, 3 to 3.5m ',
#  nan,
#  nan,
#  'White shark, 3 m',
#  nan,
#  'Shark involvement questionable',
#  "White shark, 5' to 7'",
#  'Possibly a juvenile blacktip shark',
#  'Oceanic whitetip shark, 1.8 to 2 m',
#  "4' shark",
#  "White shark, 10'",
#  nan,
#  'A small shark',
#  nan,
#  "Blue shark 6'",
#  '"A small shark"',
#  "White shark, 11' to 13'",
#  "White shark, 8' to 10'",
#  "White shark, 9'",
#  'White shark',
#  "Bull shark, 4' to 5'",
#  'Tiger shark, 100 kg',
#  'White shark, 2.5 m',
#  "Bull shark, 4' to 5'",
#  'Bull shark, 2m',
#  nan,
#  'White shark, 4 m',
#  'Seven-gill shark',
#  nan,
#  '3m shark, probably a smooth hound',
#  'Tiger shark',
#  "3' shark",
#  'Tiger shark',
#  nan,
#  "9' shark",
#  nan,
#  'Shark involvement highly doubtful',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  "Tiger shark, 12'",
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  "Bull shark, 5' to 7'",
#  nan,
#  nan,
#  'White shark',
#  "10' shark",
#  'Bull shark, 1.5',
#  nan,
#  nan,
#  'Lemon shark pup',
#  nan,
#  'Bull shark, 4 m',
#  nan,
#  'Bull shark, 1 m',
#  nan,
#  'Shark involvement not confirmed',
#  nan,
#  'a small shark',
#  'White shark, 4 m',
#  nan,
#  'Shark involvement not confirmed',
#  'Wobbegong shark, 2m',
#  'White shark',
#  'Broadnose sevengill shark, 1.5 m',
#  'Tiger shark',
#  nan,
#  nan,
#  nan,
#  " 6' to 8' shark",
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark, 3.5 m',
#  nan,
#  nan,
#  nan,
#  nan,
#  "3' to 4' shark",
#  "Tiger shark, 10'",
#  nan,
#  nan,
#  "White shark, 8' to 10'",
#  "Bull shark, 6'",
#  nan,
#  'Bull shark, 3.5 m',
#  nan,
#  "Tiger shark, 10' ",
#  'Blacktip shark',
#  'Blue shark',
#  "Nurse shark, 4'",
#  nan,
#  nan,
#  'reef shark, 1m',
#  nan,
#  "White shark, 10' to 12'",
#  'Angel shark',
#  'dogfish shark',
#  nan,
#  'Tawny nurse shark',
#  "3' to 4' shark",
#  nan,
#  "Caribbean reef shark, 4.5'",
#  'White shark',
#  "3' to 5' shark",
#  "3' to 4' shark",
#  "5' shark",
#  "3' to 4' shark",
#  "3' shark",
#  "Said to involve an 8' shark but more likely damage caused by debris",
#  nan,
#  '3+ m shark',
#  'Mako shark',
#  '3 m shark',
#  'White shark',
#  nan,
#  "5' shark",
#  nan,
#  "Bull shark, 4' to 5'",
#  nan,
#  "Blacktip shark, 4'",
#  "Nurse shark, 2'",
#  nan,
#  "Mako shark, 1.5 m [5'] ",
#  "Bull shark, 6'",
#  nan,
#  'White shark',
#  'Wobbegong shark',
#  'Grey reef shark, 2 m',
#  'Grey reef shark, 2 m',
#  "Bull shark, 7'",
#  'Tiger shark, 2.5 m',
#  "5' to 6' shark",
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bronze whaler',
#  'Sandtiger shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Sandtiger shark',
#  "Reef shark, 5'",
#  nan,
#  'Bull sharks x 2',
#  "Tiger shark, 14'",
#  'Blacktip shark',
#  '3 m shark',
#  'White shark, 3 m',
#  "Silky shark, 6.5'",
#  "9' shark",
#  "Bronze whaler shark, 6'",
#  'Tiger shark, 1.5 m ',
#  'Bull shark',
#  nan,
#  'Galapagos shark',
#  "Spinner shark, 7'",
#  'Bull shark, 2.8 to 3.1 m',
#  'Shark involvement not confirmed',
#  nan,
#  "3' to 5' shark",
#  nan,
#  nan,
#  'White shark, 3 to 3.5m ',
#  "5' shark",
#  "Spinner shark, 5'",
#  'No shark involvement',
#  "Tiger shark, 7'",
#  'Hammerhead sp.',
#  nan,
#  "Tiger shark, 13' ",
#  nan,
#  nan,
#  "4' to 5' shark",
#  "Blacktip shark, 4' to 5'",
#  "Blacktip shark, 5' to 6'",
#  nan,
#  "White shark, 19'",
#  'juvenile shark',
#  "Tiger shark, 13'",
#  "4' shark",
#  nan,
#  nan,
#  "6' shark",
#  "White shark, 11' to 12'",
#  'Hammerhead shark.',
#  'White shark, 2.5 m',
#  'small shark',
#  "White shark, 11' to 12'",
#  "White shark, 10' to 12' ",
#  nan,
#  "4' shark",
#  "3' shark",
#  "White shark, 13'",
#  'Shark involvement not confirmed',
#  "Hammerhead shark. 6' to 7'",
#  'White shark',
#  "Blacktip or spinner shark, 4'",
#  "Thought to involve a 3' to 4' shark, but shark involvement not confirmed",
#  'White shark, 3.9 to 4.2 m',
#  'Mako shark, 100-lb',
#  'Bronze whaler shark, 1.5m',
#  'Bull shark, 2m',
#  'White shark',
#  "White shark, 7'",
#  "6' shark",
#  'White shark',
#  'White shark',
#  "6' to 7' shark",
#  "4' to 5' shark",
#  'Bull shark',
#  'White shark',
#  'White shark, 2m to 3 m',
#  "4' shark",
#  'Wobbegong shark',
#  nan,
#  'Sandtiger shark',
#  'White shark',
#  'small shark',
#  nan,
#  nan,
#  'Bull shark',
#  'Bull shark',
#  "4' shark",
#  "Bull shark, 5'",
#  'small nurse shark',
#  'Bull shark, 2.5 m',
#  nan,
#  nan,
#  '1m to 1.2 m shark',
#  "6' shark",
#  'Bull shark, 3.5 m',
#  'White shark',
#  'White shark, 3.5 m',
#  nan,
#  '3- to 4-foot shark',
#  'White shark, 6 m',
#  'White shark, 3 m',
#  'Blue shark, 8 to 9 feet',
#  'Bull shark',
#  'Bull shark',
#  'No shark involvement',
#  'White shark, 4 m',
#  'Mako shark',
#  'Tiger shark, 8 to 12 feet',
#  'Blacktip shark',
#  nan,
#  'Blacktip Reef shark ',
#  'Tiger shark, 3.5 m',
#  '3.5 to 4 m shark',
#  '2 m to  3 m shark',
#  'Bull shark, 1.3 m',
#  "4' shark",
#  nan,
#  '5 m shark',
#  '1.5 m shark',
#  'White shark or oceanic whitetip shark',
#  'Raggedtooth shark, 1.3 m',
#  '"A small shark"',
#  'White shark, 4 to 5 m',
#  "White shark, 8' to 10'",
#  '1.5 m shark',
#  'Tiger shark',
#  nan,
#  "2' shark",
#  '1.5 m shark',
#  nan,
#  "Tiger shark, 12'",
#  nan,
#  'Tiger shark',
#  "12' to 14' shark",
#  '1 m shark',
#  "Bull shark, 3' to 4'",
#  'Blacktip shark',
#  nan,
#  'Blacktip shark',
#  "White shark, 18' to 20'",
#  'White shark',
#  "8' to 10' shark",
#  '2 white shark: 13\' & 9"8"',
#  'Blacktip shark',
#  "7' shark",
#  'Bull shark',
#  "White shark, 12' to 14'",
#  "3' to 4' shark",
#  'Spinner shark',
#  'Spinner shark or blacktip shark',
#  'small shark',
#  "4' to 6' shark",
#  'reef shark',
#  " Bull shark, 8'",
#  nan,
#  " Bull shark, 5'",
#  "4' tp 5' shark",
#  nan,
#  'White shark',
#  'Possibly juvenile tiger shark',
#  '1.8 metre shark',
#  nan,
#  "6' to 8' shark",
#  "4' shark",
#  'Shark involvement not confirmed',
#  nan,
#  " White shark, 7' ",
#  "4' to 5' shark",
#  "Oceanic whitetip shark'",
#  "Caribbean reef shark, 7' to 8'",
#  nan,
#  " Sandbar shark, 3' to 4'",
#  'Bronze whaler shark, 1.5m',
#  nan,
#  nan,
#  'Bull shark',
#  ' Bull shark, 1.2m ',
#  '3m shark',
#  ' Tawney nurse shark, 1m',
#  nan,
#  " white shark, 15' ",
#  'Shark involvement not confirmed',
#  "4' to 5' shark",
#  "3' shark",
#  nan,
#  nan,
#  ' Raggedtooth shark, 2m',
#  nan,
#  nan,
#  '3 m to 4 m white shark',
#  'Shark involvement prior to death not confirmed',
#  '2 m shark',
#  nan,
#  'Wobbegong shark',
#  'Blacktip or spinner shark?',
#  'Blacktip reef shark ',
#  nan,
#  '7-gill shark?',
#  '7-gill shark',
#  'Reported to involve a bull shark',
#  'White shark, 3m ',
#  "Tiger shark, 10' to 12'",
#  "4' to 6' shark",
#  ' Wobbegong shark, 1.6 to 1.8m ',
#  nan,
#  'Tiger shark, 3m ',
#  'Thought to involve a white shark',
#  "White shark, 10 '",
#  'Reported to involve a white shark',
#  nan,
#  nan,
#  'Tiger shark',
#  'Blacktip reef shark, 1m',
#  'Thought to involve a bull shark',
#  'Reported to involve a 4 m white shark',
#  'Wobbegong shark',
#  "Whitetip reef shark, 4' to 6'",
#  'Tiger shark',
#  'Nurse shark?',
#  'White shark',
#  'White shark',
#  "White shark, 8' to 10'",
#  'Small bull shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bull shark',
#  "3' shark",
#  "3' shark",
#  "3' shark",
#  nan,
#  "4' shark",
#  'Salmon shark',
#  "Mako shark, 5'",
#  nan,
#  nan,
#  'White shark',
#  'Tiger shark?',
#  nan,
#  "Bull shark, 8'",
#  "Bull shark, 6' to 8'",
#  nan,
#  "6' shark",
#  "Tiger shark, 8' to 10' ",
#  'Nurse shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'White shark',
#  "4' to 5' shark",
#  "Tiger shark, 14'",
#  nan,
#  "4' to 5' shark",
#  "Lemon shark, 4'",
#  "6' shark",
#  'Galapagos shark',
#  nan,
#  nan,
#  'Galapagos shark',
#  'Bull shark',
#  'a small shark',
#  'Tiger shark',
#  'Grey nurse shark, 3m',
#  "3' shark",
#  'Bull shark',
#  'Possibly a blacktip reef shark',
#  "4' shark",
#  'Raggedtooth shark, 1.5 m',
#  'Tiger shark, 4.8 m',
#  'Bronze whaler shark, 2.5m',
#  '"small sharks"',
#  'White shark, 4m',
#  'reef shark?',
#  "Blacktip shark, 4' to 5'",
#  'Lemon shark',
#  "Tiger shark, 15'",
#  nan,
#  '2.5 m shark',
#  'Bull shark, 2m ',
#  'Tiger shark',
#  "Tiger shark, 6'",
#  "10' shark",
#  'Sandtiger shark',
#  "Tiger shark, 10'",
#  '2.5 m shark',
#  "2' to 3' shark",
#  "Tiger shark, 15'",
#  "Tiger shark, 8'",
#  'White shark',
#  "Tiger shark, 10' to 12' ",
#  "White shark, 15' to 16' ",
#  nan,
#  "6' to 8' shark",
#  nan,
#  '2m shark',
#  "5' shark",
#  "4' shark",
#  nan,
#  'Possibly a 3 m bull shark',
#  nan,
#  nan,
#  nan,
#  nan,
#  "3.5' to 4' shark",
#  "3.5' to 4' shark",
#  "Porbeagle shark, 7'",
#  nan,
#  nan,
#  "Lemon shark, 4' to 5' ",
#  'Bull shark',
#  nan,
#  'White shark or bronze whaler',
#  nan,
#  'Thought to involve a white shark',
#  'White shark, 5m',
#  nan,
#  "14' to 18'shark",
#  "15' shark",
#  'possibly a bull shark',
#  nan,
#  'a small reef shark',
#  nan,
#  '3 m shark',
#  nan,
#  'Nurse shark',
#  'small blacktip shark?',
#  'Shark involvement not confirmed',
#  'small blacktip shark?',
#  'Blacktip shark ',
#  '1.5 m shark',
#  'Blue shark, 2.5m',
#  'White shark, 2 m',
#  nan,
#  '18" to 24" shark',
#  'Bull shark, 3m',
#  "4' to 5' shark",
#  "Tiger shark, 8' to 9' ",
#  'White shark',
#  nan,
#  'White shark',
#  "5' shark",
#  'White shark, 4 m to 5m ',
#  'White shark, 6m ',
#  "Tiger shark, 10'  ",
#  'White shark, 4m ',
#  nan,
#  'Possibly a bull shark',
#  "Possibly a 5' to 6' bull shark",
#  "4' to 5' shark",
#  "4' to 5' shark",
#  'Tawny nurse shark, 40cm',
#  nan,
#  "4' shark",
#  'Spinner shark',
#  'Grey nurse shark',
#  nan,
#  'Tiger shark, 3m',
#  'Blue shark, 70-kg blue shark',
#  'White shark, 2.7 m',
#  'Thought to involve a bull shark',
#  'White shark',
#  '2 m shark',
#  'Allegedly a 4 m tiger shark',
#  nan,
#  nan,
#  nan,
#  'White shark, 2.5m',
#  'Wobbegong shark',
#  nan,
#  nan,
#  'Wobbegong shark?',
#  nan,
#  'White shark',
#  "8' to 10' shark",
#  "White shark, 10'",
#  "White shark, 15'",
#  'Port Jackson shark, 1m',
#  nan,
#  '2 to 2.5 m shark',
#  'No shark involvement',
#  'White shark',
#  "Bull shark, 6'",
#  nan,
#  nan,
#  "4' to 6' shark",
#  nan,
#  'Tiger shark, 2m',
#  'White shark',
#  "6' shark, possibly a blactip or spinner shark",
#  "6' shark",
#  'Shark involvement prior to death not confirmed',
#  nan,
#  "White shark, >6'",
#  "Possibly a 5' to 6' sandtiger shark",
#  '4 m shark',
#  'Grey reef shark ',
#  nan,
#  "Bull shark, 6'",
#  'Shark involvement not confirmed',
#  nan,
#  nan,
#  'White shark, 3m to 4m',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bull shark, 3m female',
#  "Bull shark, 6'",
#  "White shark, 5' k",
#  nan,
#  "5' shark",
#  nan,
#  nan,
#  "Blacktip shark, 4'",
#  "Sevengill shark, 6' to 8'",
#  "3' to 4' shark",
#  nan,
#  'White shark',
#  "Tiger shark, 10'",
#  'Tiger shark',
#  'Zambesi shark',
#  nan,
#  ' Tiger shark, 2.8m',
#  nan,
#  "Bull shark, 12'",
#  'reef shark, 1.5m',
#  "1' to 2' shark",
#  'possibly a bronze whaler shark',
#  ' Bull shark, 2.5 m',
#  nan,
#  'Bull shark, 2.5m',
#  nan,
#  '3 m to 4 m shark',
#  'Bull shark, 2m',
#  '1.5 m shark',
#  nan,
#  'White shark x 2',
#  '1 m shark',
#  nan,
#  "6' shark",
#  'Caribbean reef shark',
#  'Shark involvement not confirmed',
#  nan,
#  "6' shark",
#  nan,
#  'Oceanic whitetip shark, 2.5m ',
#  'Mako shark ',
#  'Mako shark',
#  'Oceanic whitetip shark, 2.5m, female',
#  'Oceanic whitetip shark, 2.5m, female',
#  nan,
#  'White shark',
#  'White shark',
#  "Porbeagle shark, 8' ",
#  "White shark, 14' to 18' ",
#  'Bull shark, 1.4m ',
#  "Possibly a 6' lemon shark",
#  nan,
#  'White shark',
#  nan,
#  'White shark',
#  '2m shark',
#  "3' shark",
#  nan,
#  nan,
#  nan,
#  'White shark',
#  'White shark',
#  nan,
#  nan,
#  nan,
#  '3 m shark',
#  "White shark, 15'",
#  "3' to 4' shark",
#  "4' shark",
#  nan,
#  'Possibly a small blacktip shark',
#  "Sandtiger shark, 4' to 5'",
#  'A small spinner shark',
#  'Angel shark',
#  "Blue shark, 7'",
#  "4' shark",
#  "8' shark",
#  "Bull shark, 5'",
#  nan,
#  '1 m shark',
#  "4' shark",
#  nan,
#  "Lemon shark, 4'",
#  '20 to 30kg shark',
#  '20 to 30kg shark',
#  nan,
#  "4' shark",
#  "Lemon shark, 6'",
#  "14' shark",
#  '2 m shark',
#  "Oceanic whitetip shark, 6'",
#  '1.5 m shark',
#  '3 m shark',
#  nan,
#  '2 m shark',
#  'Wobbegong shark, 1.6m',
#  'White shark, 2.5m',
#  "Spinner shark, 6'",
#  'Invalid',
#  nan,
#  '1.5 m shark',
#  'Thought to involve a juvenile hammerhead shark',
#  nan,
#  'White shark',
#  'Whitetip reef shark, 1m',
#  nan,
#  nan,
#  nan,
#  'Zambesi shark, 2m ',
#  'Bull shark, 3m',
#  nan,
#  'White shark, 2.8 to 3 m ',
#  nan,
#  "Sandtiger shark, 8'",
#  'Shark involvement not confirmed',
#  "6' shark",
#  'Thresher shark',
#  nan,
#  nan,
#  "4' shark",
#  '2 m shark',
#  nan,
#  'White shark, 4m',
#  nan,
#  "6' to 8' shark",
#  nan,
#  'Angel shark',
#  'Spurdog',
#  "Bull shark, 8'",
#  'Shark involvement prior to death not confirmed',
#  nan,
#  "4' shark",
#  'White shark',
#  "White shark, 5' to 6' juvenile ",
#  'White shark, 2m',
#  nan,
#  'Tiger shark, 12',
#  'Bull shark?',
#  nan,
#  nan,
#  nan,
#  'Shark involvement questionable',
#  nan,
#  nan,
#  "5' shark",
#  nan,
#  nan,
#  "Nurse shark, 6'",
#  'Thought to involve a Bronze whale shark, 2m',
#  'Shark involvement probable, but not confirmed',
#  'Oceanic whitetip shark, 2.5 to 3m',
#  '80 kg shark',
#  "5' to 8' shark",
#  'blacktip or spinner shark',
#  'blacktip or spinner shark',
#  'blacktip or spinner shark',
#  "Blacktip shark, 4'",
#  nan,
#  nan,
#  nan,
#  "2' to 3' shark",
#  "2' to 3' shark",
#  'Shark involvement not confirmed',
#  "White shark, 12' to 15' female",
#  nan,
#  'Raggedtooth shark',
#  nan,
#  'Bronze whaler shark?',
#  "3' to 4' shark",
#  'Thought to involve a cookie cutter shark',
#  'Wobbegong shark, 60cm',
#  nan,
#  'Blue shark, 1m',
#  '2.6 m shark',
#  'White shark, 2.5m ',
#  'Bull shark, 2.7 m ',
#  "White shark, 12' ",
#  'Bull shark',
#  nan,
#  'Tiger shark',
#  'White shark, 5.5 m ',
#  'Dusky shark, 2m',
#  'White shark, 5m',
#  'White shark, 3.5m',
#  'Broadnose sevengill shark',
#  'White shark, 4m to 5m ',
#  '4 to 5m white shark',
#  'White shark',
#  'Raggedtooth shark, 2m',
#  'Oceanic whitetip shark',
#  nan,
#  'Grey nurse shark, 3m',
#  'Lemon shark',
#  ' reef shark, 1.8m',
#  nan,
#  nan,
#  '5 m white shark',
#  nan,
#  "+3' shark",
#  'Bronze whaler shark',
#  "2' to 3' juvenile shark",
#  'Tiger shark',
#  "White shark, 14' to 16' ",
#  '3 m shark',
#  nan,
#  nan,
#  "4' shark",
#  'Shark involvement not confirmed',
#  'Blue shark',
#  nan,
#  "6' shark",
#  nan,
#  'Shark involvement not confirmed',
#  nan,
#  "8' bull shark or Caribbean reef shark",
#  nan,
#  "Tiger shark, 12'",
#  "8' white shark or 7-gill shark",
#  "3'  shark",
#  "2' to 3' reef shark",
#  nan,
#  nan,
#  "3' shark",
#  "3' to 4' shark",
#  nan,
#  "4' shark",
#  nan,
#  nan,
#  'Shark involvement prior to death not confirmed',
#  "Bull shark, 6' to 7'",
#  'White shark, 2m',
#  nan,
#  "4.5 to 5' shark",
#  "White shark, 15'",
#  nan,
#  "5' shark",
#  'Bull shark',
#  nan,
#  '3 m shark',
#  '2 m shark',
#  nan,
#  'White shark, 4m',
#  '2 small bull sharks',
#  nan,
#  'Tiger shark',
#  "4' shark",
#  nan,
#  'Bull shark, 1.8m',
#  nan,
#  "White shark, 12' to 15'",
#  nan,
#  'Reported by media as shark attack, but shark involvement prior to death was not confirmed',
#  'Shark involvement not confirmed; thought to be a barracuda bite',
#  "1.5' to 2' shark",
#  "6' shark",
#  'Bull shark',
#  nan,
#  "4' to 5' shark",
#  "2.5' shark",
#  nan,
#  'Shark involvement not confirmed',
#  'White shark',
#  'A bull shark, according to some of the divers on the boat',
#  nan,
#  '1 m shark',
#  'Blacktip shark, 2m',
#  'Mako shark, 90kg',
#  'a small shark',
#  '3 m shark',
#  '2 m shark',
#  '"a small shark"',
#  'Not a shark attack; it was a hoax',
#  'Tiger shark',
#  '2.27 m shark',
#  'reef shark',
#  '1.5 to 2 m shark',
#  "4' to 5' shark",
#  "5' shark",
#  'White shark, 3m to 4m',
#  'Tiger shark',
#  'White shark, 2.5m ',
#  'Bronze whaler shark',
#  "3' to 4' shark",
#  "Blacktip shark, 5'",
#  'Tiger shark',
#  'Caribbean reef shark',
#  'White shark',
#  'Oceanic whitetip sharks were in the vicinity',
#  "3' shark",
#  'Gray reef shark',
#  nan,
#  "9.5' shark?",
#  "Nurse shark, 2' to 3' ",
#  nan,
#  nan,
#  nan,
#  '18" to 24" shark',
#  'Possibly a spinner shark',
#  "Tiger shark, 10' to 12' ",
#  "White shark, 12'",
#  "3' shark",
#  "3' shark",
#  'Sandtiger shark',
#  nan,
#  "4' to 5' shark",
#  nan,
#  "Possibly a 6' bull shark",
#  ' ',
#  nan,
#  nan,
#  nan,
#  "Possibly a 10' bull shark",
#  nan,
#  nan,
#  'White shark',
#  ' ',
#  'Bronze whaler shark, 1.5 m ',
#  "2' to 3' shark",
#  "3' small spotted catshark, Scyliorhinus canicula",
#  'Shark involvement not confirmed',
#  "5' shark",
#  "Bull shark, 5' ",
#  nan,
#  '2 m shark',
#  "4' shark",
#  'Tiger shark',
#  'Shark involvement not confirmed',
#  "3' to 4' shark",
#  'A 10-year-old 94-pound pregnant blacktip reef shark',
#  'Lesser spotted dogfish, Scyliorhinus canicula, less than 80 cm in length',
#  '2.5 m shark',
#  "10' shark",
#  "4' to 5' shark",
#  'Shark involvement prior to death was not confirmed',
#  "Tiger shark, 14' ",
#  "6' to 8' shark",
#  '"a small shark"',
#  'blacktip or spinner shark',
#  "3' to 4' shark",
#  'Tiger shark',
#  nan,
#  "3' shark",
#  "4' to 5' shark",
#  '1.5 m shark',
#  '2 to 2.5 m shark',
#  nan,
#  'Tiger shark',
#  nan,
#  'Tiger shark',
#  'White shark, 3m',
#  'Tiger shark',
#  '2.4 m shark',
#  '24" to 30" shark',
#  "6' to 8' shark, possibly a tiger shark",
#  '2.5 to 3 m shark',
#  '2 to 3 m shark',
#  "White shark, 12' to 15' ",
#  'Raggedtooth shark, 150-kg',
#  'White shark, 5m ',
#  '2 m to 3 m shark',
#  'Bull shark, 1.5m ',
#  "White shark, 16' ",
#  nan,
#  "3' to 3.5' shark",
#  nan,
#  'Spinner shark',
#  "5' shark",
#  'No shark involvement',
#  "3' shark",
#  nan,
#  'White shark, 3.5m ',
#  nan,
#  "Bronze whaler shark, 6'",
#  ...]

# %%
# We can filter the species by the proper name of the shark, everything else is redundant

sharks_nona_2["Species"] = sharks_nona_2["Species"].str.extract(r"([A-Z|a-z]{4,}\sshark)")
display_errors(sharks_nona_2)
sharks_nona_2.sample(5)
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of NAs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Month</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>221</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>78</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>1478</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of Nuls</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Month</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>221</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>78</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>1478</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Number of Duplicates</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>2874</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>
#      Month  Year        Type    Country  \
# 4043   Nov  1959  Unprovoked  AUSTRALIA
# 5573   Aug  1899  Unprovoked     EGYPT
# 196    Dec  2016    Provoked  AUSTRALIA
# 4284   Aug  1955    Provoked        USA
# 268    Jun  2016  Unprovoked      EGYPT
#
#                                           Location      Activity Sex Age  \
# 4043                        Fairhaven Beach, Lorne  Body surfing   M  19
# 5573                                     Port Said       Bathing   M  19
# 196                                      Merimbula  Surf fishing   M  20
# 4284  Zuma Beach, Santa Monica, Los Angeles County       Surfing   M  25
# 268                                     Ain Sokhna      Swimming   M  23
#
#                                                  Injury Fatal (Y/N)     Time  \
# 4043                Thighs bitten, right hand lacerated           N    14h45
# 5573                       Forearm, wrist & hand bitten           N    09h30
# 196   Lacerations to both hands while attempting to ...           N    02h00
# 4284  Surfer grabbed shark, which turned & bit him a...           N      NaN
# 268           Leg severely bitten, surgically amputated           N  Morning
#
#               Species
# 4043              NaN
# 5573              NaN
# 196   Wobbegong shark
# 4284       blue shark
# 268        Mako shark

# %%
# We can capitalize the shark types
sharks_nona_2["Species"] = sharks_nona_2["Species"].str.capitalize()

# %%
check = sharks_nona_2["Species"].value_counts()

print(check.to_string())
# Out:
# White shark           475
# Tiger shark           186
# Bull shark            135
# Nurse shark            64
# Blacktip shark         54
# Whaler shark           52
# Reef shark             43
# Small shark            40
# Spinner shark          40
# Raggedtooth shark      35
# Wobbegong shark        30
# Mako shark             25
# Hammerhead shark       23
# Zambesi shark          22
# Blue shark             21
# Lemon shark            21
# Whitetip shark         14
# Sand shark             13
# Sandtiger shark        13
# Dusky shark            10
# Sevengill shark         7
# Galapagos shark         6
# Copper shark            5
# Porbeagle shark         5
# Sandbar shark           5
# Juvenile shark          5
# Gill shark              5
# Angel shark             4
# Silky shark             4
# Colored shark           4
# Zambezi shark           3
# Carpet shark            3
# Brown shark             2
# Foot shark              1
# Banjo shark             1
# Hooked shark            1
# Unidentified shark      1
# Larger shark            1
# Another shark           1
# Bonita shark            1
# Nose shark              1
# Nosed shark             1
# Grey shark              1
# Cookiecutter shark      1
# Young shark             1
# Bonnethed shark         1
# Metre shark             1
# Same shark              1
# Cutter shark            1
# Whale shark             1
# Thresher shark          1
# Dogfish shark           1
# Jackson shark           1
# Salmon shark            1
# Carcharhinid shark      1

# %%
sharks_nona_2.sample(3)
# Out:
#      Month  Year        Type    Country                         Location  \
# 1538   Oct  2005    Provoked        USA      Ponce Inlet, Volusia County
# 1023   Jun  2010  Unprovoked  AUSTRALIA  Conspicuous Beach, near Walpole
# 1592   Apr  2005    Provoked  AUSTRALIA                         Bermagui
#
#      Activity Sex Age                                             Injury  \
# 1538   Wading   M  15  Minor cuts to dorsum & sole of left foot when ...
# 1023  Surfing   M  40                    Severe laceration to right knee
# 1592  Fishing   M  25         Laceration on left thigh PROVOKED INCIDENT
#
#      Fatal (Y/N)   Time     Species
# 1538           N  17h55         NaN
# 1023           N  12h00         NaN
# 1592           N  23h00  Mako shark

# %% [markdown]
# ## Cleaning the Age column

# %%
list(sharks_nona_2["Age"])
# Out:
# ['57',
#  '11',
#  '48',
#  '18',
#  '52',
#  '15',
#  '12',
#  '32',
#  '10',
#  '21',
#  nan,
#  '30',
#  nan,
#  '60',
#  nan,
#  '32',
#  '33',
#  '29',
#  '54',
#  '37',
#  nan,
#  '56',
#  '12',
#  '19',
#  '25',
#  '10',
#  '69',
#  '18',
#  '38',
#  '55',
#  '34',
#  '35',
#  nan,
#  '46',
#  '45',
#  '14',
#  '18',
#  '40s',
#  nan,
#  '28',
#  '20',
#  '54',
#  '35',
#  '24',
#  '26',
#  '49',
#  '25',
#  '14',
#  '25',
#  '22',
#  '7',
#  '31',
#  '17',
#  '60',
#  '15',
#  nan,
#  nan,
#  '54',
#  '40',
#  nan,
#  nan,
#  '33',
#  nan,
#  '13',
#  '28',
#  '18',
#  '35',
#  '42',
#  '17',
#  '37',
#  '3',
#  '11',
#  '69',
#  '13',
#  '20',
#  '34',
#  nan,
#  '15',
#  '10',
#  '37',
#  nan,
#  '40',
#  '40',
#  '50',
#  nan,
#  nan,
#  '46',
#  '32',
#  '13',
#  '14',
#  '34',
#  '82',
#  '48',
#  nan,
#  '19',
#  '30',
#  '32',
#  '20',
#  nan,
#  '41',
#  '29',
#  '33',
#  '18',
#  '14',
#  '33',
#  '28',
#  '20s',
#  '40',
#  '17',
#  '28',
#  '17',
#  '35',
#  '10',
#  '21',
#  '51',
#  '39',
#  '17',
#  '58',
#  '30',
#  nan,
#  '25',
#  nan,
#  '26',
#  '22',
#  nan,
#  '21',
#  '55',
#  '57',
#  '48',
#  '47',
#  '20',
#  '16',
#  nan,
#  '55',
#  '61',
#  '19',
#  '20',
#  '65',
#  '73',
#  '58',
#  '41',
#  '42',
#  '36',
#  '36',
#  '66',
#  '25',
#  '29',
#  '21',
#  '32',
#  '17',
#  '16',
#  '36',
#  '43',
#  '43',
#  '60s',
#  '51',
#  '50',
#  '12',
#  '22',
#  '25',
#  '37',
#  '20',
#  '49',
#  '21',
#  '22',
#  '40',
#  '43',
#  '18',
#  '29',
#  '31',
#  '9',
#  '61',
#  '10',
#  '59',
#  '42',
#  '34',
#  '35',
#  '11',
#  '59',
#  '43',
#  '42',
#  nan,
#  '19',
#  '6',
#  '19',
#  '27',
#  '64',
#  '60',
#  '23',
#  nan,
#  '29',
#  '52',
#  '13',
#  '57',
#  '22',
#  '11',
#  '48',
#  '23',
#  '59',
#  '39',
#  '24',
#  '15',
#  nan,
#  '12',
#  '22',
#  '26',
#  '26',
#  '69',
#  '34',
#  '46',
#  '22',
#  '41',
#  '19',
#  nan,
#  '41',
#  '21',
#  '31',
#  '45',
#  '40',
#  '41',
#  nan,
#  '15',
#  nan,
#  '48',
#  '11',
#  '31',
#  nan,
#  '38',
#  '71',
#  '43',
#  '32',
#  '26',
#  '22',
#  '55',
#  '28',
#  '20',
#  '9',
#  '54',
#  '28',
#  '19',
#  '10',
#  '42',
#  '21',
#  '21',
#  '32',
#  '44',
#  nan,
#  '9',
#  '25',
#  '18',
#  '22',
#  '13',
#  '14',
#  '22',
#  '7',
#  nan,
#  '14',
#  '27',
#  '12',
#  '16',
#  '20',
#  '42',
#  '50',
#  '29',
#  '62',
#  '37',
#  '54',
#  '21',
#  '38',
#  '15',
#  '10',
#  '22',
#  '10',
#  '57',
#  '52',
#  '25',
#  '35',
#  '46',
#  '31',
#  '40',
#  '45',
#  '34',
#  '38',
#  '23',
#  '52',
#  '32',
#  '68',
#  '12',
#  '18',
#  '19',
#  '23',
#  '43',
#  '19',
#  '47',
#  '6',
#  '37',
#  '9',
#  '36',
#  '10',
#  '16',
#  '12',
#  '13',
#  '11',
#  '17',
#  '47',
#  '14',
#  '19',
#  '19',
#  '30',
#  '50',
#  nan,
#  '29',
#  '65',
#  '63',
#  '26',
#  '71',
#  '48',
#  '13',
#  '70',
#  '23',
#  '36',
#  '52',
#  '58',
#  '9',
#  '36',
#  '18 months',
#  '22',
#  '41',
#  '35',
#  '57',
#  '20',
#  '24',
#  nan,
#  '17',
#  '34',
#  '15',
#  '12',
#  '17',
#  '50',
#  '40s',
#  '17',
#  '13',
#  '44',
#  '53',
#  '18',
#  '34',
#  '20',
#  nan,
#  nan,
#  '13',
#  '7',
#  '29',
#  '40',
#  '15',
#  nan,
#  nan,
#  '28',
#  '23',
#  '36',
#  '50',
#  '43',
#  '20s',
#  '52',
#  '13',
#  '17',
#  '30s',
#  '29',
#  '31',
#  nan,
#  '10',
#  '7',
#  '10',
#  '8',
#  '20',
#  'Teen',
#  '51',
#  '8',
#  '61',
#  '39',
#  '63',
#  '14',
#  nan,
#  '19',
#  '48',
#  '42',
#  '15',
#  '16',
#  '39',
#  '43',
#  '14',
#  '22',
#  '29',
#  nan,
#  '10',
#  '38',
#  '35',
#  '12',
#  '40',
#  '23',
#  '42',
#  '25',
#  nan,
#  'teen',
#  'teen',
#  '63',
#  '38',
#  '66',
#  '42',
#  nan,
#  '21',
#  '21',
#  '28',
#  '28',
#  '24',
#  '37',
#  '19',
#  '29',
#  '30',
#  '26',
#  '57',
#  '19',
#  '35',
#  '25',
#  nan,
#  '77',
#  '16',
#  '46',
#  '60',
#  '24',
#  nan,
#  '41',
#  '45',
#  '25',
#  '6',
#  '74',
#  '55',
#  '45',
#  '12',
#  '50',
#  '27',
#  '7',
#  '45',
#  '21',
#  '13',
#  '43',
#  '25',
#  '17',
#  '9',
#  nan,
#  '50',
#  '11',
#  '16',
#  nan,
#  '20',
#  '19',
#  '10',
#  '17',
#  '56',
#  '40',
#  '18',
#  '64',
#  '50',
#  '18',
#  '50',
#  '15',
#  '63',
#  nan,
#  '14',
#  '28',
#  '15',
#  '10',
#  '58',
#  nan,
#  '32',
#  '11',
#  '30',
#  '29',
#  '36',
#  '16',
#  '34',
#  '51',
#  '9',
#  '21',
#  '53',
#  '58',
#  '30',
#  '68',
#  '28',
#  '28 & 26',
#  '46',
#  nan,
#  '16',
#  '48',
#  '43',
#  '26',
#  '23',
#  '29',
#  '20',
#  '32',
#  '60',
#  '31',
#  '61',
#  '32',
#  '14',
#  '30',
#  '43',
#  '25',
#  '51',
#  '39',
#  '24',
#  '55',
#  '42',
#  '11',
#  '21',
#  '22',
#  '52',
#  '29',
#  '25',
#  '30s',
#  '37',
#  '32',
#  '8',
#  '56',
#  '53',
#  '34',
#  '18',
#  '56',
#  '39',
#  '17',
#  '48',
#  '44',
#  '50',
#  '24',
#  '43',
#  '52',
#  '29',
#  '6',
#  '26',
#  '16',
#  '12',
#  '62',
#  '6',
#  '23',
#  '18',
#  nan,
#  nan,
#  '16',
#  '42',
#  '57',
#  '30',
#  '25',
#  '33',
#  '46',
#  '22',
#  nan,
#  '30',
#  '47',
#  '15',
#  '28',
#  '20',
#  '27',
#  '28',
#  '33',
#  '21',
#  '20',
#  '61',
#  '15',
#  '17',
#  '34',
#  '31',
#  '19',
#  nan,
#  nan,
#  '29',
#  '26',
#  '24',
#  '44',
#  '25',
#  '53',
#  '28',
#  '34',
#  '23',
#  '27',
#  '35',
#  '51',
#  '14',
#  '63',
#  '18',
#  '10',
#  '42',
#  '27',
#  '26',
#  '32',
#  '41',
#  '50',
#  '64',
#  '51',
#  '27',
#  '43',
#  '21',
#  '5',
#  '38',
#  '25',
#  '37',
#  '30',
#  '21',
#  '19',
#  '19',
#  '48',
#  '39',
#  '49',
#  '20s',
#  '25',
#  '32',
#  '27',
#  '30',
#  '7',
#  '54',
#  '36',
#  '29',
#  '6',
#  '54',
#  '12',
#  '16',
#  '17',
#  '28',
#  '21',
#  '22',
#  '10',
#  nan,
#  '20',
#  '35',
#  '15',
#  '31',
#  '28',
#  '28',
#  '19',
#  '22',
#  '33',
#  nan,
#  nan,
#  '28',
#  '86',
#  '15',
#  '37',
#  '32',
#  '17',
#  '49',
#  '41',
#  nan,
#  '27',
#  '48',
#  '30',
#  '24',
#  '36',
#  '21',
#  '32',
#  '49',
#  nan,
#  '58',
#  '38',
#  '55',
#  '7',
#  '16',
#  '16',
#  '46',
#  '70',
#  '54',
#  '46',
#  '70',
#  '48',
#  '21',
#  nan,
#  '20',
#  '30',
#  '19',
#  '22',
#  nan,
#  'Teen',
#  '29',
#  '18',
#  '29',
#  '15',
#  '27',
#  '24',
#  '24',
#  '10',
#  '31',
#  '45',
#  '16',
#  '47',
#  '25',
#  '35',
#  nan,
#  '37',
#  '16',
#  '20',
#  '10',
#  '13',
#  '55',
#  '9',
#  '20',
#  '19',
#  '48',
#  '20',
#  '13',
#  '17',
#  '18',
#  '40',
#  '49',
#  '58',
#  '60',
#  '59',
#  '10',
#  '29',
#  '68',
#  '35',
#  '24',
#  '34',
#  nan,
#  '19',
#  '60',
#  '46',
#  '18',
#  nan,
#  '31',
#  '38',
#  '14',
#  '29',
#  '54',
#  '37',
#  '9',
#  '32',
#  '20',
#  '55',
#  '27',
#  '18',
#  '22',
#  '24',
#  '39',
#  '58',
#  '49',
#  '10',
#  '31',
#  '22',
#  '27',
#  '18',
#  '25',
#  '21',
#  '27',
#  '17',
#  '54',
#  '10',
#  '23',
#  '39',
#  nan,
#  '60',
#  '15',
#  nan,
#  '25',
#  '22',
#  nan,
#  '26',
#  nan,
#  '56',
#  '14',
#  '41',
#  '14',
#  '11',
#  '26',
#  '19',
#  nan,
#  '37',
#  '12',
#  '43',
#  '52',
#  '14',
#  '50',
#  '46',
#  nan,
#  '31',
#  '49',
#  '55',
#  '27',
#  '20',
#  '23',
#  '52',
#  '31',
#  '40',
#  '24',
#  nan,
#  '15',
#  '59',
#  '16',
#  '17',
#  '17',
#  '61',
#  '21',
#  '19',
#  '40',
#  '15',
#  '33',
#  '31',
#  '41',
#  '15',
#  '19',
#  '25',
#  nan,
#  '24',
#  '13',
#  '31',
#  '49',
#  '29',
#  '51',
#  nan,
#  '15',
#  nan,
#  '39',
#  '34',
#  '24',
#  '50',
#  '15',
#  '11',
#  '43',
#  '44',
#  '40',
#  '43',
#  '32',
#  '40',
#  nan,
#  '51',
#  '43',
#  '15',
#  '52',
#  '27',
#  '52',
#  '19',
#  '26',
#  '20',
#  '20',
#  '47',
#  '38',
#  '13',
#  nan,
#  '31',
#  nan,
#  nan,
#  '17',
#  '44',
#  '9',
#  '8',
#  '15',
#  '16',
#  '24',
#  '14',
#  '53',
#  '42',
#  '46',
#  '29',
#  '37',
#  '40',
#  '35',
#  '15',
#  '14',
#  '9',
#  '49',
#  '21',
#  '28',
#  '37',
#  '40',
#  '6',
#  '24',
#  '18',
#  '24',
#  '32',
#  '21',
#  '66',
#  '14',
#  '32',
#  '19',
#  '30',
#  '15',
#  '16',
#  '18',
#  '52',
#  '13',
#  '14',
#  '8',
#  '27',
#  '49',
#  '25',
#  '14',
#  '42',
#  '20',
#  '20',
#  '24',
#  '31',
#  'teen',
#  '34',
#  '52',
#  '28',
#  '32',
#  '14',
#  '21',
#  '42',
#  '37',
#  '32',
#  '52',
#  '31',
#  '22',
#  '16',
#  '23',
#  '48',
#  nan,
#  '18 or 20',
#  '23',
#  nan,
#  '56',
#  'Teen',
#  '14',
#  '58',
#  '36',
#  '15',
#  '12',
#  '58',
#  '15',
#  '24',
#  '54',
#  '27',
#  nan,
#  '52',
#  '16',
#  '7',
#  '20',
#  '15',
#  '19',
#  '30',
#  '9',
#  '19',
#  '51',
#  '20',
#  nan,
#  '36',
#  '15',
#  '14',
#  '48',
#  '43',
#  '30',
#  '48',
#  '18',
#  '17',
#  '20',
#  nan,
#  '9',
#  nan,
#  '40',
#  '38',
#  '38',
#  '19',
#  '21',
#  '45',
#  '63',
#  '68',
#  '13',
#  '12',
#  '24',
#  '26',
#  '7',
#  '27',
#  '11',
#  '42',
#  '59',
#  '29',
#  '16',
#  '26',
#  '30',
#  '41',
#  '24',
#  nan,
#  '54',
#  '24',
#  '25',
#  '10',
#  '43',
#  '25',
#  '15',
#  '29',
#  nan,
#  '22',
#  '20',
#  '18',
#  '16',
#  '55',
#  '52',
#  '44',
#  '33',
#  '12 or 13',
#  '37',
#  '23',
#  nan,
#  ...]

# %%
sharks_nona_2["Age"] = sharks_nona_2["Age"].str.extract(r"^(\d{1,2})")
list(sharks_nona_2["Age"])
# Out:
# ['57',
#  '11',
#  '48',
#  '18',
#  '52',
#  '15',
#  '12',
#  '32',
#  '10',
#  '21',
#  nan,
#  '30',
#  nan,
#  '60',
#  nan,
#  '32',
#  '33',
#  '29',
#  '54',
#  '37',
#  nan,
#  '56',
#  '12',
#  '19',
#  '25',
#  '10',
#  '69',
#  '18',
#  '38',
#  '55',
#  '34',
#  '35',
#  nan,
#  '46',
#  '45',
#  '14',
#  '18',
#  '40',
#  nan,
#  '28',
#  '20',
#  '54',
#  '35',
#  '24',
#  '26',
#  '49',
#  '25',
#  '14',
#  '25',
#  '22',
#  '7',
#  '31',
#  '17',
#  '60',
#  '15',
#  nan,
#  nan,
#  '54',
#  '40',
#  nan,
#  nan,
#  '33',
#  nan,
#  '13',
#  '28',
#  '18',
#  '35',
#  '42',
#  '17',
#  '37',
#  '3',
#  '11',
#  '69',
#  '13',
#  '20',
#  '34',
#  nan,
#  '15',
#  '10',
#  '37',
#  nan,
#  '40',
#  '40',
#  '50',
#  nan,
#  nan,
#  '46',
#  '32',
#  '13',
#  '14',
#  '34',
#  '82',
#  '48',
#  nan,
#  '19',
#  '30',
#  '32',
#  '20',
#  nan,
#  '41',
#  '29',
#  '33',
#  '18',
#  '14',
#  '33',
#  '28',
#  '20',
#  '40',
#  '17',
#  '28',
#  '17',
#  '35',
#  '10',
#  '21',
#  '51',
#  '39',
#  '17',
#  '58',
#  '30',
#  nan,
#  '25',
#  nan,
#  '26',
#  '22',
#  nan,
#  '21',
#  '55',
#  '57',
#  '48',
#  '47',
#  '20',
#  '16',
#  nan,
#  '55',
#  '61',
#  '19',
#  '20',
#  '65',
#  '73',
#  '58',
#  '41',
#  '42',
#  '36',
#  '36',
#  '66',
#  '25',
#  '29',
#  '21',
#  '32',
#  '17',
#  '16',
#  '36',
#  '43',
#  '43',
#  '60',
#  '51',
#  '50',
#  '12',
#  '22',
#  '25',
#  '37',
#  '20',
#  '49',
#  '21',
#  '22',
#  '40',
#  '43',
#  '18',
#  '29',
#  '31',
#  '9',
#  '61',
#  '10',
#  '59',
#  '42',
#  '34',
#  '35',
#  '11',
#  '59',
#  '43',
#  '42',
#  nan,
#  '19',
#  '6',
#  '19',
#  '27',
#  '64',
#  '60',
#  '23',
#  nan,
#  '29',
#  '52',
#  '13',
#  '57',
#  '22',
#  '11',
#  '48',
#  '23',
#  '59',
#  '39',
#  '24',
#  '15',
#  nan,
#  '12',
#  '22',
#  '26',
#  '26',
#  '69',
#  '34',
#  '46',
#  '22',
#  '41',
#  '19',
#  nan,
#  '41',
#  '21',
#  '31',
#  '45',
#  '40',
#  '41',
#  nan,
#  '15',
#  nan,
#  '48',
#  '11',
#  '31',
#  nan,
#  '38',
#  '71',
#  '43',
#  '32',
#  '26',
#  '22',
#  '55',
#  '28',
#  '20',
#  '9',
#  '54',
#  '28',
#  '19',
#  '10',
#  '42',
#  '21',
#  '21',
#  '32',
#  '44',
#  nan,
#  '9',
#  '25',
#  '18',
#  '22',
#  '13',
#  '14',
#  '22',
#  '7',
#  nan,
#  '14',
#  '27',
#  '12',
#  '16',
#  '20',
#  '42',
#  '50',
#  '29',
#  '62',
#  '37',
#  '54',
#  '21',
#  '38',
#  '15',
#  '10',
#  '22',
#  '10',
#  '57',
#  '52',
#  '25',
#  '35',
#  '46',
#  '31',
#  '40',
#  '45',
#  '34',
#  '38',
#  '23',
#  '52',
#  '32',
#  '68',
#  '12',
#  '18',
#  '19',
#  '23',
#  '43',
#  '19',
#  '47',
#  '6',
#  '37',
#  '9',
#  '36',
#  '10',
#  '16',
#  '12',
#  '13',
#  '11',
#  '17',
#  '47',
#  '14',
#  '19',
#  '19',
#  '30',
#  '50',
#  nan,
#  '29',
#  '65',
#  '63',
#  '26',
#  '71',
#  '48',
#  '13',
#  '70',
#  '23',
#  '36',
#  '52',
#  '58',
#  '9',
#  '36',
#  '18',
#  '22',
#  '41',
#  '35',
#  '57',
#  '20',
#  '24',
#  nan,
#  '17',
#  '34',
#  '15',
#  '12',
#  '17',
#  '50',
#  '40',
#  '17',
#  '13',
#  '44',
#  '53',
#  '18',
#  '34',
#  '20',
#  nan,
#  nan,
#  '13',
#  '7',
#  '29',
#  '40',
#  '15',
#  nan,
#  nan,
#  '28',
#  '23',
#  '36',
#  '50',
#  '43',
#  '20',
#  '52',
#  '13',
#  '17',
#  '30',
#  '29',
#  '31',
#  nan,
#  '10',
#  '7',
#  '10',
#  '8',
#  '20',
#  nan,
#  '51',
#  '8',
#  '61',
#  '39',
#  '63',
#  '14',
#  nan,
#  '19',
#  '48',
#  '42',
#  '15',
#  '16',
#  '39',
#  '43',
#  '14',
#  '22',
#  '29',
#  nan,
#  '10',
#  '38',
#  '35',
#  '12',
#  '40',
#  '23',
#  '42',
#  '25',
#  nan,
#  nan,
#  nan,
#  '63',
#  '38',
#  '66',
#  '42',
#  nan,
#  '21',
#  '21',
#  '28',
#  '28',
#  '24',
#  '37',
#  '19',
#  '29',
#  '30',
#  '26',
#  '57',
#  '19',
#  '35',
#  '25',
#  nan,
#  '77',
#  '16',
#  '46',
#  '60',
#  '24',
#  nan,
#  '41',
#  '45',
#  '25',
#  '6',
#  '74',
#  '55',
#  '45',
#  '12',
#  '50',
#  '27',
#  '7',
#  '45',
#  '21',
#  '13',
#  '43',
#  '25',
#  '17',
#  '9',
#  nan,
#  '50',
#  '11',
#  '16',
#  nan,
#  '20',
#  '19',
#  '10',
#  '17',
#  '56',
#  '40',
#  '18',
#  '64',
#  '50',
#  '18',
#  '50',
#  '15',
#  '63',
#  nan,
#  '14',
#  '28',
#  '15',
#  '10',
#  '58',
#  nan,
#  '32',
#  '11',
#  '30',
#  '29',
#  '36',
#  '16',
#  '34',
#  '51',
#  '9',
#  '21',
#  '53',
#  '58',
#  '30',
#  '68',
#  '28',
#  '28',
#  '46',
#  nan,
#  '16',
#  '48',
#  '43',
#  '26',
#  '23',
#  '29',
#  '20',
#  '32',
#  '60',
#  '31',
#  '61',
#  '32',
#  '14',
#  '30',
#  '43',
#  '25',
#  '51',
#  '39',
#  '24',
#  '55',
#  '42',
#  '11',
#  '21',
#  '22',
#  '52',
#  '29',
#  '25',
#  '30',
#  '37',
#  '32',
#  '8',
#  '56',
#  '53',
#  '34',
#  '18',
#  '56',
#  '39',
#  '17',
#  '48',
#  '44',
#  '50',
#  '24',
#  '43',
#  '52',
#  '29',
#  '6',
#  '26',
#  '16',
#  '12',
#  '62',
#  '6',
#  '23',
#  '18',
#  nan,
#  nan,
#  '16',
#  '42',
#  '57',
#  '30',
#  '25',
#  '33',
#  '46',
#  '22',
#  nan,
#  '30',
#  '47',
#  '15',
#  '28',
#  '20',
#  '27',
#  '28',
#  '33',
#  '21',
#  '20',
#  '61',
#  '15',
#  '17',
#  '34',
#  '31',
#  '19',
#  nan,
#  nan,
#  '29',
#  '26',
#  '24',
#  '44',
#  '25',
#  '53',
#  '28',
#  '34',
#  '23',
#  '27',
#  '35',
#  '51',
#  '14',
#  '63',
#  '18',
#  '10',
#  '42',
#  '27',
#  '26',
#  '32',
#  '41',
#  '50',
#  '64',
#  '51',
#  '27',
#  '43',
#  '21',
#  '5',
#  '38',
#  '25',
#  '37',
#  '30',
#  '21',
#  '19',
#  '19',
#  '48',
#  '39',
#  '49',
#  '20',
#  '25',
#  '32',
#  '27',
#  '30',
#  '7',
#  '54',
#  '36',
#  '29',
#  '6',
#  '54',
#  '12',
#  '16',
#  '17',
#  '28',
#  '21',
#  '22',
#  '10',
#  nan,
#  '20',
#  '35',
#  '15',
#  '31',
#  '28',
#  '28',
#  '19',
#  '22',
#  '33',
#  nan,
#  nan,
#  '28',
#  '86',
#  '15',
#  '37',
#  '32',
#  '17',
#  '49',
#  '41',
#  nan,
#  '27',
#  '48',
#  '30',
#  '24',
#  '36',
#  '21',
#  '32',
#  '49',
#  nan,
#  '58',
#  '38',
#  '55',
#  '7',
#  '16',
#  '16',
#  '46',
#  '70',
#  '54',
#  '46',
#  '70',
#  '48',
#  '21',
#  nan,
#  '20',
#  '30',
#  '19',
#  '22',
#  nan,
#  nan,
#  '29',
#  '18',
#  '29',
#  '15',
#  '27',
#  '24',
#  '24',
#  '10',
#  '31',
#  '45',
#  '16',
#  '47',
#  '25',
#  '35',
#  nan,
#  '37',
#  '16',
#  '20',
#  '10',
#  '13',
#  '55',
#  '9',
#  '20',
#  '19',
#  '48',
#  '20',
#  '13',
#  '17',
#  '18',
#  '40',
#  '49',
#  '58',
#  '60',
#  '59',
#  '10',
#  '29',
#  '68',
#  '35',
#  '24',
#  '34',
#  nan,
#  '19',
#  '60',
#  '46',
#  '18',
#  nan,
#  '31',
#  '38',
#  '14',
#  '29',
#  '54',
#  '37',
#  '9',
#  '32',
#  '20',
#  '55',
#  '27',
#  '18',
#  '22',
#  '24',
#  '39',
#  '58',
#  '49',
#  '10',
#  '31',
#  '22',
#  '27',
#  '18',
#  '25',
#  '21',
#  '27',
#  '17',
#  '54',
#  '10',
#  '23',
#  '39',
#  nan,
#  '60',
#  '15',
#  nan,
#  '25',
#  '22',
#  nan,
#  '26',
#  nan,
#  '56',
#  '14',
#  '41',
#  '14',
#  '11',
#  '26',
#  '19',
#  nan,
#  '37',
#  '12',
#  '43',
#  '52',
#  '14',
#  '50',
#  '46',
#  nan,
#  '31',
#  '49',
#  '55',
#  '27',
#  '20',
#  '23',
#  '52',
#  '31',
#  '40',
#  '24',
#  nan,
#  '15',
#  '59',
#  '16',
#  '17',
#  '17',
#  '61',
#  '21',
#  '19',
#  '40',
#  '15',
#  '33',
#  '31',
#  '41',
#  '15',
#  '19',
#  '25',
#  nan,
#  '24',
#  '13',
#  '31',
#  '49',
#  '29',
#  '51',
#  nan,
#  '15',
#  nan,
#  '39',
#  '34',
#  '24',
#  '50',
#  '15',
#  '11',
#  '43',
#  '44',
#  '40',
#  '43',
#  '32',
#  '40',
#  nan,
#  '51',
#  '43',
#  '15',
#  '52',
#  '27',
#  '52',
#  '19',
#  '26',
#  '20',
#  '20',
#  '47',
#  '38',
#  '13',
#  nan,
#  '31',
#  nan,
#  nan,
#  '17',
#  '44',
#  '9',
#  '8',
#  '15',
#  '16',
#  '24',
#  '14',
#  '53',
#  '42',
#  '46',
#  '29',
#  '37',
#  '40',
#  '35',
#  '15',
#  '14',
#  '9',
#  '49',
#  '21',
#  '28',
#  '37',
#  '40',
#  '6',
#  '24',
#  '18',
#  '24',
#  '32',
#  '21',
#  '66',
#  '14',
#  '32',
#  '19',
#  '30',
#  '15',
#  '16',
#  '18',
#  '52',
#  '13',
#  '14',
#  '8',
#  '27',
#  '49',
#  '25',
#  '14',
#  '42',
#  '20',
#  '20',
#  '24',
#  '31',
#  nan,
#  '34',
#  '52',
#  '28',
#  '32',
#  '14',
#  '21',
#  '42',
#  '37',
#  '32',
#  '52',
#  '31',
#  '22',
#  '16',
#  '23',
#  '48',
#  nan,
#  '18',
#  '23',
#  nan,
#  '56',
#  nan,
#  '14',
#  '58',
#  '36',
#  '15',
#  '12',
#  '58',
#  '15',
#  '24',
#  '54',
#  '27',
#  nan,
#  '52',
#  '16',
#  '7',
#  '20',
#  '15',
#  '19',
#  '30',
#  '9',
#  '19',
#  '51',
#  '20',
#  nan,
#  '36',
#  '15',
#  '14',
#  '48',
#  '43',
#  '30',
#  '48',
#  '18',
#  '17',
#  '20',
#  nan,
#  '9',
#  nan,
#  '40',
#  '38',
#  '38',
#  '19',
#  '21',
#  '45',
#  '63',
#  '68',
#  '13',
#  '12',
#  '24',
#  '26',
#  '7',
#  '27',
#  '11',
#  '42',
#  '59',
#  '29',
#  '16',
#  '26',
#  '30',
#  '41',
#  '24',
#  nan,
#  '54',
#  '24',
#  '25',
#  '10',
#  '43',
#  '25',
#  '15',
#  '29',
#  nan,
#  '22',
#  '20',
#  '18',
#  '16',
#  '55',
#  '52',
#  '44',
#  '33',
#  '12',
#  '37',
#  '23',
#  nan,
#  ...]

# %% [markdown]
# ## Cleaning the Country column

# %%
check2 = sharks_nona_2["Country"].value_counts()
print(check2.to_string())
# Out:
# USA                                      1359
# AUSTRALIA                                 626
# SOUTH AFRICA                              342
# BAHAMAS                                    47
# NEW ZEALAND                                44
# BRAZIL                                     42
# REUNION                                    35
# MEXICO                                     26
# PAPUA NEW GUINEA                           22
# MOZAMBIQUE                                 20
# NEW CALEDONIA                              19
# EGYPT                                      16
# FIJI                                       15
# SPAIN                                      14
# ITALY                                      13
# JAPAN                                      12
# FRENCH POLYNESIA                           11
# CROATIA                                     9
# CUBA                                        7
# PHILIPPINES                                 6
# TAIWAN                                      6
# PANAMA                                      6
# ECUADOR                                     6
# BERMUDA                                     5
# CHILE                                       5
# INDONESIA                                   5
# TONGA                                       5
# JAMAICA                                     4
# INDIA                                       4
# COSTA RICA                                  4
# GREECE                                      4
# ENGLAND                                     4
# THAILAND                                    4
# HONG KONG                                   4
# SOUTH KOREA                                 4
# NEW BRITAIN                                 4
# UNITED KINGDOM                              4
# VIETNAM                                     4
# VANUATU                                     3
# SOLOMON ISLANDS                             3
# MICRONESIA                                  3
# VENEZUELA                                   3
# PACIFIC OCEAN                               3
# KENYA                                       3
# PALAU                                       3
# GRENADA                                     3
# OKINAWA                                     3
# GUAM                                        3
# SCOTLAND                                    3
# COLUMBIA                                    3
# TURKS & CAICOS                              3
# SOUTH ATLANTIC OCEAN                        2
# ST HELENA, British overseas territory       2
# EGYPT                                       2
# FRANCE                                      2
# AMERICAN SAMOA                              2
# MAURITIUS                                   2
# MADAGASCAR                                  2
# TANZANIA                                    2
# ISRAEL                                      2
# MARSHALL ISLANDS                            2
# SEYCHELLES                                  2
# MALTA                                       2
# NICARAGUA                                   1
# NORTH PACIFIC OCEAN                         1
# GUINEA                                      1
# BRITISH WEST INDIES                         1
# YEMEN                                       1
# IRAQ                                        1
# SRI LANKA                                   1
# MID ATLANTIC OCEAN                          1
# PERSIAN GULF                                1
# IRAN                                        1
# HAITI                                       1
# NORTH SEA                                   1
# CYPRUS                                      1
# NEW GUINEA                                  1
# EL SALVADOR                                 1
# ARGENTINA                                   1
# SENEGAL                                     1
# ANDAMAN / NICOBAR ISLANDAS                  1
# FEDERATED STATES OF MICRONESIA              1
# ST. MAARTIN                                 1
# PACIFIC OCEAN                               1
# SINGAPORE                                   1
# MALDIVES                                    1
# MALAYSIA                                    1
# UNITED ARAB EMIRATES                        1
# PUERTO RICO                                 1
# ST. MARTIN                                  1
# PALESTINIAN TERRITORIES                     1
# RUSSIA                                      1
# DOMINICAN REPUBLIC                          1
# UNITED ARAB EMIRATES (UAE)                  1
# NORWAY                                      1
# GRAND CAYMAN                                1
# CHINA                                       1
# URUGUAY                                     1
# CANADA                                      1
#  TONGA                                      1
# EGYPT / ISRAEL                              1
# CARIBBEAN SEA                               1
# PORTUGAL                                    1
# WESTERN SAMOA                               1
# BRITISH ISLES                               1
# TURKEY                                      1
# BARBADOS                                    1

# %%
sharks_nona_2["Country"] = sharks_nona_2["Country"].str.title().replace("Islandas", "Islands").replace("St Helena, British Overseas Territory", "St Helena").replace("Usa", "USA").replace("United Arab Emirates (Uae)", "UAE").replace(" Tonga", "Tonga")

check3 = sharks_nona_2["Country"].value_counts()
print(check3.to_string())
# Out:
# USA                               1359
# Australia                          626
# South Africa                       342
# Bahamas                             47
# New Zealand                         44
# Brazil                              42
# Reunion                             35
# Mexico                              26
# Papua New Guinea                    22
# Mozambique                          20
# New Caledonia                       19
# Egypt                               16
# Fiji                                15
# Spain                               14
# Italy                               13
# Japan                               12
# French Polynesia                    11
# Croatia                              9
# Cuba                                 7
# Panama                               6
# Ecuador                              6
# Tonga                                6
# Taiwan                               6
# Philippines                          6
# Chile                                5
# Indonesia                            5
# Bermuda                              5
# Hong Kong                            4
# India                                4
# Vietnam                              4
# South Korea                          4
# New Britain                          4
# Greece                               4
# Jamaica                              4
# United Kingdom                       4
# England                              4
# Costa Rica                           4
# Thailand                             4
# Grenada                              3
# Palau                                3
# Kenya                                3
# Okinawa                              3
# Pacific Ocean                        3
# Micronesia                           3
# Venezuela                            3
# Scotland                             3
# Vanuatu                              3
# Solomon Islands                      3
# Turks & Caicos                       3
# Guam                                 3
# Columbia                             3
# Mauritius                            2
# Seychelles                           2
# South Atlantic Ocean                 2
# Marshall Islands                     2
# Tanzania                             2
# France                               2
# Egypt                                2
# Israel                               2
# Malta                                2
# Madagascar                           2
# St Helena                            2
# American Samoa                       2
# Mid Atlantic Ocean                   1
# Haiti                                1
# British West Indies                  1
# Nicaragua                            1
# Persian Gulf                         1
# North Pacific Ocean                  1
# North Sea                            1
# Yemen                                1
# Sri Lanka                            1
# Federated States Of Micronesia       1
# Andaman / Nicobar Islandas           1
# Cyprus                               1
# Iraq                                 1
# Guinea                               1
# Argentina                            1
# El Salvador                          1
# Iran                                 1
# Senegal                              1
# St. Maartin                          1
# New Guinea                           1
# Pacific Ocean                        1
# Maldives                             1
# Malaysia                             1
# United Arab Emirates                 1
# Puerto Rico                          1
# St. Martin                           1
# Palestinian Territories              1
# Russia                               1
# Dominican Republic                   1
# UAE                                  1
# Norway                               1
# Grand Cayman                         1
# China                                1
# Uruguay                              1
# Canada                               1
# Egypt / Israel                       1
# Caribbean Sea                        1
# Portugal                             1
# Western Samoa                        1
# British Isles                        1
# Turkey                               1
# Singapore                            1
# Barbados                             1

# %% [markdown]
# ## Cleaning the Sex column

# %%
display(sharks_nona_2["Sex"].unique())

sharks_nona_2["Sex"] = sharks_nona_2["Sex"].str.replace("M ", "M")

display(sharks_nona_2["Sex"].unique())
# Out:
# array(['F', 'M', 'M ', 'lli', nan], dtype=object)
# array(['F', 'M', 'lli', nan], dtype=object)

# %% [markdown]
# ## Cleaning the Fatality column

# %%
display(sharks_nona_2["Fatal (Y/N)"].unique())

sharks_nona_2["Fatal (Y/N)"] = sharks_nona_2["Fatal (Y/N)"].str.replace(" N", "N")
sharks_nona_2["Fatal (Y/N)"] = sharks_nona_2["Fatal (Y/N)"].str.extract(r"(N$|Y$)")

display(sharks_nona_2["Fatal (Y/N)"].unique())
# Out:
# array(['N', 'Y', nan, 'M', '2017', 'UNKNOWN', ' N'], dtype=object)
# array(['N', 'Y', nan], dtype=object)

# %% [markdown]
# ## Cleaning the Type column

# %%
display(sharks_nona_2["Type"].unique())
display(sharks_nona_2["Type"].value_counts())

sharks_nona_2["Type"] = sharks_nona_2["Type"].str.replace("Boatinging", "Boating").replace("Boat", "Boating").replace("Sea Disaster", "Unprovoked")
sharks_nona_2["Type"] = sharks_nona_2["Type"].str.extract(r"(Unprovoked|Provoked)")
display(sharks_nona_2["Type"].value_counts())
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Boat', 'Sea Disaster'], dtype=object)
# Unprovoked      2462
# Provoked         239
# Invalid           95
# Boating           45
# Sea Disaster      21
# Boat              10
# Questionable       2
# Name: Type, dtype: int64
# Unprovoked    2483
# Provoked       239
# Name: Type, dtype: int64

# %% [markdown]
# ## Renaming

# %%
sharks_clean = sharks_nona_2

# %% [markdown]
# ## Resetting indexes

# %%
sharks_clean.reset_index()
# Out:
#       index Month  Year        Type       Country  \
# 0         0   Jun  2018         NaN           USA
# 1         1   Jun  2018  Unprovoked           USA
# 2         2   Jun  2018         NaN           USA
# 3         6   Jun  2018  Unprovoked        Brazil
# 4         7   May  2018  Unprovoked           USA
# ...     ...   ...   ...         ...           ...
# 2869   5991   Mar  1858  Unprovoked     Australia
# 2870   6021   Feb  1852  Unprovoked  South Africa
# 2871   6077   Jan  1837  Unprovoked     Australia
# 2872   6114   May  1817  Unprovoked     Sri Lanka
# 2873   6160   Mar  1703  Unprovoked      Barbados
#
#                                                Location  \
# 0                           Oceanside, San Diego County
# 1                        St. Simon Island, Glynn County
# 2                                          Habush, Oahu
# 3                                 Piedade Beach, Recife
# 4     Lighhouse Point Park, Ponce Inlet, Volusia County
# ...                                                 ...
# 2869                                         Hobson Bay
# 2870                                       Danger Point
# 2871                                      Macleay River
# 2872                                            Colombo
# 2873                                       Carlisle Bay
#
#                                Activity Sex  Age  \
# 0                              Paddling   F   57
# 1                              Standing   F   11
# 2                               Surfing   M   48
# 3                              Swimming   M   18
# 4                               Fishing   M   52
# ...                                 ...  ..  ...
# 2869                            Bathing   M   22
# 2870  Wreck of the steamship Birkenhead   M  NaN
# 2871                   Washing his feet   M   12
# 2872                           Swimming   M   22
# 2873                           Swimming   M   19
#
#                                                  Injury Fatal (Y/N)  \
# 0     No injury to occupant, outrigger canoe and pad...           N
# 1                            Minor injury to left thigh           N
# 2          Injury to left lower leg from surfboard skeg           N
# 3                                                 FATAL           Y
# 4               Minor injury to foot. PROVOKED INCIDENT           N
# ...                                                 ...         ...
# 2869                                              FATAL           Y
# 2870  FATAL. All of the women & children on board su...           Y
# 2871        FATAL     Injured by shark, died of tetanus           Y
# 2872                                              FATAL           Y
# 2873  Hand and foot severely bitten, surgically ampu...           N
#
#                 Time      Species
# 0              18h00  White shark
# 1      14h00  -15h00          NaN
# 2              07h45          NaN
# 3     Late afternoon  Tiger shark
# 4                NaN  Lemon shark
# ...              ...          ...
# 2869           15h00          NaN
# 2870           01h50  White shark
# 2871         Evening          NaN
# 2872         Evening          NaN
# 2873           Night          NaN
#
# [2874 rows x 13 columns]

# %% [markdown]
# # Reviewing the final dataset

# %%
display(sharks_clean.head())

display_errors(sharks_clean)

sharks_clean.shape
# Out:
#   Month  Year        Type Country  \
# 0   Jun  2018         NaN     USA
# 1   Jun  2018  Unprovoked     USA
# 2   Jun  2018         NaN     USA
# 6   Jun  2018  Unprovoked  Brazil
# 7   May  2018  Unprovoked     USA
#
#                                             Location  Activity Sex Age  \
# 0                        Oceanside, San Diego County  Paddling   F  57
# 1                     St. Simon Island, Glynn County  Standing   F  11
# 2                                       Habush, Oahu   Surfing   M  48
# 6                              Piedade Beach, Recife  Swimming   M  18
# 7  Lighhouse Point Park, Ponce Inlet, Volusia County   Fishing   M  52
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 6                                              FATAL           Y
# 7            Minor injury to foot. PROVOKED INCIDENT           N
#
#              Time      Species
# 0           18h00  White shark
# 1   14h00  -15h00          NaN
# 2           07h45          NaN
# 6  Late afternoon  Tiger shark
# 7             NaN  Lemon shark
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of NAs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Month</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>152</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>244</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>1478</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Sum of Nuls</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Month</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <td>152</td>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Location</th>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>Activity</th>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>244</td>
#     </tr>
#     <tr>
#       <th>Injury</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Fatal (Y/N)</th>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>Time</th>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>Species</th>
#       <td>1478</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Number of Duplicates</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>False</th>
#       <td>2874</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>
# (2874, 12)

# %% [markdown]
# By doing all these extractions, the non-extracted values remain as NaN. We can confirm it because the rows haven't changed. This is what I wanted, because deleting the non-extracted may lead to deleting information in other cells containing valuable information.

# %% [markdown]
# # Cleaned dataset

# %% [markdown]
# At this point, I consider the table ready to be analyzed properly be taking the right columns. Data extraction & visualization will be taken place in a separated notebook

# %%
sharks_clean.to_csv("../data/attacks_cleaned.csv", index = False)
